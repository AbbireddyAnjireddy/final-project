# %% [markdown]
# # Check Python version
# !python --version

# %%
import numpy as np
import pandas as pd
from google.colab import userdata
import google.generativeai as genai
import os
from google.colab import data_table
from vega_datasets import data

# %%
 # !pip install -q -U google-generativeai

# %%
# GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')


genai.configure(api_key="AIzaSyCMBd2kY53TjpfsApED_BuIVSY37F4BREc")

# %%
model = genai.GenerativeModel('Gemini 2.0 Flash')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -U gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !gdown --folder https://drive.google.com/drive/folders/1IhTy0VlkN6SEafeF3i8THixz7flOe_sl -O ALLAPIS --quiet

# %%
# Define the path to the CSV file inside your custom folder
csv_path = '/content/ALLAPIS/CEAS_08.csv'

# Check if file exists and load it
if os.path.exists(csv_path):
    print("✅ File found! Reading the CSV now...\n")
    df = pd.read_csv(csv_path)
   # display(df.head(10))  # Display first 10 rows
else:
    print("❌ File not found at:", csv_path)
# Out:
# ✅ File found! Reading the CSV now...

# %%
# Locating the file in the drive
import os

def find_folder_path(folder_name, base_path='/content/'):
    for root, dirs, files in os.walk(base_path):
        if folder_name in dirs:
            return os.path.join(root, folder_name)
    return None

# %%
# Printing the path of the file
folder_name_to_search = '04 Manikanth and Anjireddy'
path = "/content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy"
# find_folder_path(folder_name_to_search)
print(path)
# Out:
# /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy

# %%
data_table.enable_dataframe_formatter()
df.head(3)
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
#
#                         receiver                             date  \
# 0    user4@gvc.ceas-challenge.cc  Tue, 05 Aug 2008 16:31:02 -0700
# 1  user2.2@gvc.ceas-challenge.cc  Tue, 05 Aug 2008 18:31:03 -0500
# 2  user2.9@gvc.ceas-challenge.cc  Tue, 05 Aug 2008 20:28:00 -1200
#
#                      subject  \
# 0  Never agree to be a loser
# 1     Befriend Jenna Jameson
# 2       CNN.com Daily Top 10
#
#                                                 body  label  urls
# 0  Buck up, your troubles caused by small dimensi...      1     1
# 1  \nUpgrade your sex and pleasures with these te...      1     1
# 2  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1     1

# %% [markdown]
# #preprocessing the data like remove duplicates and missing values

# %%
#  Step 1: Remove duplicate rows
df = df.drop_duplicates()
from google.colab import data_table
from IPython.display import HTML
# df1 = df.head(3)
# data_table.DataTable(df)
data_table.DataTable(df.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#       <th>label</th>
#       <th>urls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Step 2: Remove rows with any missing (NaN) values
df = df.dropna()
data_table.DataTable(df.head(2), include_index=True, num_rows_per_page=5)

# print(df1.head(3))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#       <th>label</th>
#       <th>urls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Optional: Reset index for clean row numbering
df.reset_index(drop=True, inplace=True)
data_table.DataTable(df.head(2), include_index=True, num_rows_per_page=5)
# print(df1.head(3))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#       <th>label</th>
#       <th>urls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
from google.colab import data_table
from vega_datasets import data

data_table.enable_dataframe_formatter()
df.head(10)
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3                 Michael Parker <ivqrnai@pobox.com>
# 4  Gretchen Suggs <externalsep1@loanofficertool.com>
# 5  Caroline Aragon <dwthaidomainnamesm@thaidomain...
# 6    Replica Watches <jhorton@thebakercompanies.com>
# 7             Daily Top 10 <acidirev_1972@tcwpg.com>
# 8                  qydlqcws-iacfym@issues.apache.org
# 9      Daily Top 10 <orn|dent_1973@musicaedischi.it>
#
#                                          receiver  \
# 0                     user4@gvc.ceas-challenge.cc
# 1                   user2.2@gvc.ceas-challenge.cc
# 2                   user2.9@gvc.ceas-challenge.cc
# 3  SpamAssassin Dev <xrh@spamassassin.apache.org>
# 4                   user2.2@gvc.ceas-challenge.cc
# 5                user7-ext5@gvc.ceas-challenge.cc
# 6                  user2.10@gvc.ceas-challenge.cc
# 7                   user2.3@gvc.ceas-challenge.cc
# 8                     xrh@spamassassin.apache.org
# 9                     user7@gvc.ceas-challenge.cc
#
#                               date  \
# 0  Tue, 05 Aug 2008 16:31:02 -0700
# 1  Tue, 05 Aug 2008 18:31:03 -0500
# 2  Tue, 05 Aug 2008 20:28:00 -1200
# 3  Tue, 05 Aug 2008 17:31:20 -0600
# 4  Tue, 05 Aug 2008 19:31:21 -0400
# 5  Wed, 06 Aug 2008 05:31:22 +0600
# 6  Tue, 05 Aug 2008 21:44:01 +0000
# 7  Tue, 05 Aug 2008 20:41:14 -0300
# 8  Tue, 05 Aug 2008 15:31:03 -0800
# 9  Wed, 06 Aug 2008 00:31:38 +0100
#
#                                              subject  \
# 0                          Never agree to be a loser
# 1                             Befriend Jenna Jameson
# 2                               CNN.com Daily Top 10
# 3  Re: svn commit: r619753 - in /spamassassin/tru...
# 4                         SpecialPricesPharmMoreinfo
# 5                               From Caroline Aragon
# 6                                    Replica Watches
# 7                               CNN.com Daily Top 10
# 8  [Bug 5780] URI processing turns uuencoded stri...
# 9                               CNN.com Daily Top 10
#
#                                                 body  label  urls
# 0  Buck up, your troubles caused by small dimensi...      1     1
# 1  \nUpgrade your sex and pleasures with these te...      1     1
# 2  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1     1
# 3  Would anyone object to removing .so from this ...      0     1
# 4  \nWelcomeFastShippingCustomerSupport\nhttp://7...      1     1
# 5  \n\n\n\n\nYo wu urS mo ou go rc ebo eForM rgi ...      1     0
# 6  We have fake Swiss Men's and Ladie's Replica \...      1     0
# 7  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1     1
# 8  http://issues.apache.org/SpamAssassin/show_bug...      0     1
# 9  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...      1     1

# %%
# Define path to save the cleaned file
save_path = '/content/ALLAPIS/cleaned_data.csv'

# Save the cleaned DataFrame as CSV
df.to_csv(save_path, index=False)

print(f"✅ Cleaned data saved to: {save_path}")
# Out:
# ✅ Cleaned data saved to: /content/ALLAPIS/cleaned_data.csv

# %% [markdown]
# #Extracting the data into header,body and header and body

# %% [markdown]
# #Data with labels

# %%
#  Header-only DataFrame with label
df_header_label = df[['sender', 'receiver', 'date', 'subject', 'label']].copy()
data_table.DataTable(df_header_label.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#  Body-only DataFrame with label
df_body_label = df[['body','label']].copy()
data_table.DataTable(df_body_label.head(10), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>body</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Would anyone object to removing .so from this ...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>\nWelcomeFastShippingCustomerSupport\nhttp://7...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>\n\n\n\n\nYo wu urS mo ou go rc ebo eForM rgi ...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>We have fake Swiss Men's and Ladie's Replica \...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>http://issues.apache.org/SpamAssassin/show_bug...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# getting header and body  with label
df_header_body_label = df[['sender', 'receiver', 'date', 'subject', 'body','label']].copy()
data_table.DataTable(df_header_body_label.head(10), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#       <th>label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Daily Top 10 &lt;Karmandeep-opengevl@universalnet...</td>
#       <td>user2.9@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 20:28:00 -1200</td>
#       <td>CNN.com Daily Top 10</td>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Michael Parker &lt;ivqrnai@pobox.com&gt;</td>
#       <td>SpamAssassin Dev &lt;xrh@spamassassin.apache.org&gt;</td>
#       <td>Tue, 05 Aug 2008 17:31:20 -0600</td>
#       <td>Re: svn commit: r619753 - in /spamassassin/tru...</td>
#       <td>Would anyone object to removing .so from this ...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Gretchen Suggs &lt;externalsep1@loanofficertool.com&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 19:31:21 -0400</td>
#       <td>SpecialPricesPharmMoreinfo</td>
#       <td>\nWelcomeFastShippingCustomerSupport\nhttp://7...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Caroline Aragon &lt;dwthaidomainnamesm@thaidomain...</td>
#       <td>user7-ext5@gvc.ceas-challenge.cc</td>
#       <td>Wed, 06 Aug 2008 05:31:22 +0600</td>
#       <td>From Caroline Aragon</td>
#       <td>\n\n\n\n\nYo wu urS mo ou go rc ebo eForM rgi ...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Replica Watches &lt;jhorton@thebakercompanies.com&gt;</td>
#       <td>user2.10@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 21:44:01 +0000</td>
#       <td>Replica Watches</td>
#       <td>We have fake Swiss Men's and Ladie's Replica \...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Daily Top 10 &lt;acidirev_1972@tcwpg.com&gt;</td>
#       <td>user2.3@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 20:41:14 -0300</td>
#       <td>CNN.com Daily Top 10</td>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>qydlqcws-iacfym@issues.apache.org</td>
#       <td>xrh@spamassassin.apache.org</td>
#       <td>Tue, 05 Aug 2008 15:31:03 -0800</td>
#       <td>[Bug 5780] URI processing turns uuencoded stri...</td>
#       <td>http://issues.apache.org/SpamAssassin/show_bug...</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Daily Top 10 &lt;orn|dent_1973@musicaedischi.it&gt;</td>
#       <td>user7@gvc.ceas-challenge.cc</td>
#       <td>Wed, 06 Aug 2008 00:31:38 +0100</td>
#       <td>CNN.com Daily Top 10</td>
#       <td>&gt;+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Define your full target path
submission_folder = path
print(submission_folder)
gemini_llm_path = os.path.join(submission_folder,'001 Submission','All APIs',  'gemini_llm', 'raw_data','Data_with_label')

#  Create the directory structure
os.makedirs(gemini_llm_path, exist_ok=True)

# Save the 3 labeled DataFrames to the new location

# 1. Header with label
df_header_label.to_csv(os.path.join(gemini_llm_path, 'header_with_label.csv'), index=False)

# 2. Body with label
df_body_label.to_csv(os.path.join(gemini_llm_path, 'body_with_label.csv'), index=False)

# 3. Combined Header + Body with label
df_header_body_label.to_csv(os.path.join(gemini_llm_path, 'header_body_with_label.csv'), index=False)

print(f"✅ All files saved successfully to: {gemini_llm_path}")
# Out:
# /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy
# ✅ All files saved successfully to: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/raw_data/Data_with_label

# %% [markdown]
# #Data without label

# %%
#. Header-only DataFrame with no label
df_header_label = df[['sender', 'receiver', 'date', 'subject']].copy()
data_table.DataTable(df_header_label.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Body-only DataFrame with no label
df_body_label = df[['body']].copy()
data_table.DataTable(df_body_label.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>body</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#  Combined header + body DataFrame with no label
df_header_body_label = df[['sender', 'receiver', 'date', 'subject', 'body']].copy()
data_table.DataTable(df_header_body_label.head(2), include_index=True, num_rows_per_page=5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sender</th>
#       <th>receiver</th>
#       <th>date</th>
#       <th>subject</th>
#       <th>body</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Young Esposito &lt;Young@iworld.de&gt;</td>
#       <td>user4@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 16:31:02 -0700</td>
#       <td>Never agree to be a loser</td>
#       <td>Buck up, your troubles caused by small dimensi...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Mok &lt;ipline's1983@icable.ph&gt;</td>
#       <td>user2.2@gvc.ceas-challenge.cc</td>
#       <td>Tue, 05 Aug 2008 18:31:03 -0500</td>
#       <td>Befriend Jenna Jameson</td>
#       <td>\nUpgrade your sex and pleasures with these te...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# Define your full target path
submission_folder = path
gemini_llm_path = os.path.join(submission_folder,'001 Submission','All APIs',  'gemini_llm', 'prompt_data','All_data')

# Create the directory structure
os.makedirs(gemini_llm_path, exist_ok=True)

# Save the 3 labeled DataFrames to the new location

# 1. Header with label
df_header_label.to_csv(os.path.join(gemini_llm_path, 'header_without_label.csv'), index=False)

# 2. Body with label
df_body_label.to_csv(os.path.join(gemini_llm_path, 'body_without_label.csv'), index=False)

# 3. Combined Header + Body with label
df_header_body_label.to_csv(os.path.join(gemini_llm_path, 'header_body_without_label.csv'), index=False)

print(f"✅ All files saved successfully to: {gemini_llm_path}")
# Out:
# ✅ All files saved successfully to: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/prompt_data/All_data

# %% [markdown]
# ## create sample 75 rows

# %% [markdown]
# ### 75 Data with labels

# %%
#  Define input and output folder paths
input_path =  os.path.join(path,'001 Submission','All APIs',  'gemini_llm', 'raw_data','Data_with_label')
#  '/content/drive/MyDrive/outPut_Folder/gpt_llm/raw_data/Data_with_label'
output_path = os.path.join(path,'001 Submission','All APIs',  'gemini_llm', 'raw_data','sample_75_with_labels')
# '/content/drive/MyDrive/outPut_Folder/gpt_llm/raw_data/sample_75_with_labels'
os.makedirs(output_path, exist_ok=True)  # Create output folder if not exists

# Define filenames and new names for output
files_to_sample = {
    'header_with_label.csv': 'header_sample_75_with_label.csv',
    'body_with_label.csv': 'body_sample_75_with_label.csv',
    'header_body_with_label.csv': 'header_body_sample_75_with_label.csv'
}

#  Load each file, extract 75 rows, and save to new location
for input_file, output_file in files_to_sample.items():
    full_input_path = os.path.join(input_path, input_file)
    full_output_path = os.path.join(output_path, output_file)

    # Load the full file
    df = pd.read_csv(full_input_path)

    # Extract the first 75 rows
    df_sample = df.head(75)

    # Save to the new folder
    df_sample.to_csv(full_output_path, index=False)
    print(f"✅ Saved first 75 rows of {input_file} → {full_output_path}")
# Out:
# ✅ Saved first 75 rows of header_with_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/raw_data/sample_75_with_labels/header_sample_75_with_label.csv
# ✅ Saved first 75 rows of body_with_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/raw_data/sample_75_with_labels/body_sample_75_with_label.csv
# ✅ Saved first 75 rows of header_body_with_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/raw_data/sample_75_with_labels/header_body_sample_75_with_label.csv

# %% [markdown]
# ### 75 data without labels

# %%
# Define input and output folder paths
input_path = os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'prompt_data','All_data')
# '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/All_data'
output_path = os.path.join(path,'001 Submission','All APIs',  'gemini_llm', 'prompt_data','sample_75_without_labels')
# '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels'
os.makedirs(output_path, exist_ok=True)  # Create output folder if not exists

# Define filenames and new names for output
files_to_sample = {
    'header_without_label.csv': 'header_sample_75_without_label.csv',
    'body_without_label.csv': 'body_sample_75_without_label.csv',
    'header_body_without_label.csv': 'header_body_sample_75_without_label.csv'
}

# Load each file, extract 75 rows, and save to new location
for input_file, output_file in files_to_sample.items():
    full_input_path = os.path.join(input_path, input_file)
    full_output_path = os.path.join(output_path, output_file)

    # Load the full file
    df = pd.read_csv(full_input_path)

    # Extract the first 75 rows
    df_sample = df.head(75)

    # Save to the new folder
    df_sample.to_csv(full_output_path, index=False)
    print(f"✅ Saved first 75 rows of {input_file} → {full_output_path}")
# Out:
# ✅ Saved first 75 rows of header_without_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/prompt_data/sample_75_without_labels/header_sample_75_without_label.csv
# ✅ Saved first 75 rows of body_without_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/prompt_data/sample_75_without_labels/body_sample_75_without_label.csv
# ✅ Saved first 75 rows of header_body_without_label.csv → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/prompt_data/sample_75_without_labels/header_body_sample_75_without_label.csv

# %% [markdown]
# ### printing the dataset

# %%
# Load header sample
df_header_sample = pd.read_csv(os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'prompt_data','sample_75_without_labels','header_sample_75_without_label.csv'))
# '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/header_sample_75_without_label.csv

# Load body sample
df_body_sample = pd.read_csv(os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'prompt_data','sample_75_without_labels','body_sample_75_without_label.csv'))
                            #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/body_sample_75_without_label.csv'

# Load combined header+body sample
df_combined_sample = pd.read_csv(os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'prompt_data','sample_75_without_labels','header_body_sample_75_without_label.csv'))
                                #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/header_body_sample_75_without_label.csv'

# %%
df_header_sample.head(10)
# Out:
#                                               sender  \
# 0                   Young Esposito <Young@iworld.de>
# 1                       Mok <ipline's1983@icable.ph>
# 2  Daily Top 10 <Karmandeep-opengevl@universalnet...
# 3                 Michael Parker <ivqrnai@pobox.com>
# 4  Gretchen Suggs <externalsep1@loanofficertool.com>
# 5  Caroline Aragon <dwthaidomainnamesm@thaidomain...
# 6    Replica Watches <jhorton@thebakercompanies.com>
# 7             Daily Top 10 <acidirev_1972@tcwpg.com>
# 8                  qydlqcws-iacfym@issues.apache.org
# 9      Daily Top 10 <orn|dent_1973@musicaedischi.it>
#
#                                          receiver  \
# 0                     user4@gvc.ceas-challenge.cc
# 1                   user2.2@gvc.ceas-challenge.cc
# 2                   user2.9@gvc.ceas-challenge.cc
# 3  SpamAssassin Dev <xrh@spamassassin.apache.org>
# 4                   user2.2@gvc.ceas-challenge.cc
# 5                user7-ext5@gvc.ceas-challenge.cc
# 6                  user2.10@gvc.ceas-challenge.cc
# 7                   user2.3@gvc.ceas-challenge.cc
# 8                     xrh@spamassassin.apache.org
# 9                     user7@gvc.ceas-challenge.cc
#
#                               date  \
# 0  Tue, 05 Aug 2008 16:31:02 -0700
# 1  Tue, 05 Aug 2008 18:31:03 -0500
# 2  Tue, 05 Aug 2008 20:28:00 -1200
# 3  Tue, 05 Aug 2008 17:31:20 -0600
# 4  Tue, 05 Aug 2008 19:31:21 -0400
# 5  Wed, 06 Aug 2008 05:31:22 +0600
# 6  Tue, 05 Aug 2008 21:44:01 +0000
# 7  Tue, 05 Aug 2008 20:41:14 -0300
# 8  Tue, 05 Aug 2008 15:31:03 -0800
# 9  Wed, 06 Aug 2008 00:31:38 +0100
#
#                                              subject
# 0                          Never agree to be a loser
# 1                             Befriend Jenna Jameson
# 2                               CNN.com Daily Top 10
# 3  Re: svn commit: r619753 - in /spamassassin/tru...
# 4                         SpecialPricesPharmMoreinfo
# 5                               From Caroline Aragon
# 6                                    Replica Watches
# 7                               CNN.com Daily Top 10
# 8  [Bug 5780] URI processing turns uuencoded stri...
# 9                               CNN.com Daily Top 10

# %%
df_body_sample.head(50)
# Out:
#                                                  body
# 0   Buck up, your troubles caused by small dimensi...
# 1   \nUpgrade your sex and pleasures with these te...
# 2   >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 3   Would anyone object to removing .so from this ...
# 4   \nWelcomeFastShippingCustomerSupport\nhttp://7...
# 5   \n\n\n\n\nYo wu urS mo ou go rc ebo eForM rgi ...
# 6   We have fake Swiss Men's and Ladie's Replica \...
# 7   >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 8   http://issues.apache.org/SpamAssassin/show_bug...
# 9   >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 10  \nDo Not consolidate your debt   Eliminate it!...
# 11  \nAdobe Creative Suite 3 Master Collection for...
# 12  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 13  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 14  \nexpressherbals\n \nhttp://pacelike.com\n \nF...
# 15  \nPlelim,\n\nJust to remind you that if a cert...
# 16  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 17  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 18  Carlos E. R. wrote: > -----BEGIN PGP SIGNED ME...
# 19  Steve Jacobs wrote: > ---------- Forwarded mes...
# 20  \n\n\nScienceNOW Week in Review\n\n\n\n\n\n\n\...
# 21  # New Ticket Created by  Zefram \n# Please inc...
# 22  Send Wekalist mailing list submissions to\n\ti...
# 23  Update of /cvsroot/spambayes/spambayes/spambay...
# 24  Greg Freemyer wrote:\n> All,\n> \n> I'm runnin...
# 25  #PjWmcUDemi Moore Full video without cowards.\...
# 26  Britney spears p0rn video, Jennifer Lopez pict...
# 27  Benji Weber wrote:\n> On 07/02/2008, Mike  wro...
# 28  The secret to unlocking women�s G-spots http:/...
# 29  Bacheelor, MasteerMBA, and Doctoraate diplomas...
# 30  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 31  \n\n\nLargest selection of medication products...
# 32  Usage of this formula accounts for many great ...
# 33  demerphq  wrote:\n:Nobull (Brian McCauly) repo...
# 34  Good morning all,\n\nA customer is looking for...
# 35  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 36  \nUpgrade your sex and pleasures with these te...
# 37           \t\t\t\t\t\t\t\t\t\t\t\t\t\t\tDoctors...
# 38  http://issues.apache.org/SpamAssassin/show_bug...
# 39  Become more courageous in your romantic relati...
# 40  \n\n\n\n\n\n\n         Make  a present to some...
# 41  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 42  \nnetwork curl bearberry? aromatic, imaginate ...
# 43  Hello\n\nI have just compiled crm114, there wa...
# 44  \n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n      Aug. 5,...
# 45  Sloan wrote:\n> Wolfgang Woehl wrote:\n>> Aaro...
# 46  \n\n\n\n\n\nSee a schlub like me get lucky in ...
# 47  \n\n\n \n\n\n\n\n \n\n\n\n\n\n\n\n\n\nAUG. 05,...
# 48  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...
# 49  >+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+=+...

# %%
df_combined_sample.head(2)
# Out:
#                              sender                       receiver  \
# 0  Young Esposito <Young@iworld.de>    user4@gvc.ceas-challenge.cc
# 1      Mok <ipline's1983@icable.ph>  user2.2@gvc.ceas-challenge.cc
#
#                               date                    subject  \
# 0  Tue, 05 Aug 2008 16:31:02 -0700  Never agree to be a loser
# 1  Tue, 05 Aug 2008 18:31:03 -0500     Befriend Jenna Jameson
#
#                                                 body
# 0  Buck up, your troubles caused by small dimensi...
# 1  \nUpgrade your sex and pleasures with these te...

# %% [markdown]
# # prompting

# %% [markdown]
# ## Zeroshot

# %%
def create_zeroshot_prompt(row, email_type="header"):

    if email_type == "header":
        return f"""
Classify this email header as 'Phishing' or 'Legitimate'. Then briefly explain why.

Sender: {row['sender']}
Receiver: {row['receiver']}
Subject: {row['subject']}
Date: {row['date']}

output Format: Phishing or Legitimate|Reason
"""

    elif email_type == "body":
        return f"""
Classify this email body as 'Phishing' or 'Legitimate'. Then briefly explain why.

Body: {row['body']}

output Format: Phishing or Legitimate|Reason
"""

    elif email_type == "combined":
        return f"""
Classify this email (header and body) as 'Phishing' or 'Legitimate'. Then briefly explain why.

Header:
Sender: {row['sender']}
Receiver: {row['receiver']}
Subject: {row['subject']}
Date: {row['date']}

Body:
{row['body']}

output format: Phishing or Legitimate|Reason
"""

    else:
        raise ValueError("❌ Invalid email_type specified.")

# %%
# Sends a single prompt to Gemini and returns safe Prediction & Reason
import requests
import time
def analyze_email_with_gemini(prompt):
  try:
        response = model.generate_content(prompt)
        time.sleep(0.2)  # Increased delay to 2 seconds between requests
        result_text = response.text.strip().replace("**Explanation:**", "").replace("**Reason:**", "").replace("*", "").replace("Format: ","")
        print(result_text)

        # print(result_text)
        if "|" in result_text:
            prediction, reason = result_text.split("|", 1)
        else:
            prediction, reason = result_text, "No detailed reason provided."

        prediction = prediction.replace("**Prediction:**", "").strip()

        reason = reason.replace("**Explanation:**", "").replace("**Reason:**", "").strip()
        return pd.Series([prediction.strip(), reason.strip()])  # Extract clean classification result
  except requests.exceptions.RequestException as e:
        print(f"Error during request: {e}")

# %%
# Processes a CSV file from sample_75 and saves predictions to a new Excel file in output_data
def process_sample_75_csv_to_output(file_name, email_type):
    # Construct full path to input CSV file
    input_path = os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'prompt_data','sample_75_without_labels',file_name)
        # input_path = f'/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/{file_name}'
    # Define output folder location
    output_folder = os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'output_daata','zeroshot')
    #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/output_daata/zeroshot'
    os.makedirs(output_folder, exist_ok=True)

    # Construct output filename by replacing '.csv' with '_predicted.xlsx'
    output_file = file_name.replace('.csv', '_predicted.xlsx')
    output_path = os.path.join(output_folder, output_file)

    # Load the CSV input into a pandas DataFrame
    df = pd.read_csv(input_path)

    # Apply Gemini to each row using zero-shot prompt
    df[['Prediction', 'Reason']] = df.apply(
        lambda row: analyze_email_with_gemini(create_zeroshot_prompt(row, email_type)),
        axis=1
    )

    # Convert predictions to numeric labels
    df["prediction_label"] = df["Prediction"].map(lambda x: 1 if x.strip().lower() == "phishing" else 0)

    # Reorder prediction_label column right after Prediction
    cols = df.columns.tolist()
    if "Prediction" in cols and "Reason" in cols and "prediction_label" in cols:
        pred_idx = cols.index("Prediction")
        cols.insert(pred_idx + 1, cols.pop(cols.index("prediction_label")))
        df = df[cols]

    # Save the final DataFrame as Excel file
    df.to_excel(output_path, index=False)
    print(f"✅ Processed: {file_name} → Saved to {output_path}")

# %% [markdown]
# ## Fewshot

# %%
# Pre-defined examples (few-shot) to "teach" the model before each real classification
FEW_SHOT_EXAMPLES = {
    "header": [
        {
            "sender": "admin@securebank.com",
            "receiver": "user123@gmail.com",
            "subject": "Important Account Notification",
            "date": "2024-11-05",
            "label": "Phishing",
            "reason": "The sender's email is suspicious and urges action."
        },
        {
            "sender": "newsletter@trustedsource.com",
            "receiver": "user123@gmail.com",
            "subject": "Monthly Newsletter - November",
            "date": "2024-11-01",
            "label": "Legitimate",
            "reason": "It’s a regular newsletter from a known sender."
        }
    ],
    "body": [
        {
            "body": "Your account has been locked. Click here to verify immediately: http://scam-site.com",
            "label": "Phishing",
            "reason": "Urgent tone and suspicious link included."
        },
        {
            "body": "Here is your delivery confirmation for order #12345. Thank you for shopping with us!",
            "label": "Legitimate",
            "reason": "Normal e-commerce confirmation message."
        }
    ],
    "combined": [
        {
            "sender": "alerts@paypal-security.com",
            "receiver": "user@gmail.com",
            "subject": "Verify your PayPal account now!",
            "date": "2024-11-08",
            "body": "We noticed suspicious activity. Click below to confirm.",
            "label": "Phishing",
            "reason": "Suspicious sender and urgent call-to-action."
        },
        {
            "sender": "support@github.com",
            "receiver": "user@gmail.com",
            "subject": "New login detected",
            "date": "2024-11-01",
            "body": "We noticed a new login from a different location. If this was you, no further action is required.",
            "label": "Legitimate",
            "reason": "Clear explanation, no suspicious links, from a known service."
        }
    ]
}

# %%
def create_few_shot_prompt(row, email_type="header"):
    examples = FEW_SHOT_EXAMPLES[email_type]
    prompt = "You are an email security classifier. Learn from the examples below. the the first word should be either phishing or legitimate any one word\n\n example output : Phishing or Legitimate | Reason"

    # Add compact few-shot examples
    for ex in examples:
        if email_type == "header":
            prompt += (
                f"Sender: {ex['sender']}, Subject: {ex['subject']}, Date: {ex['date']}\n"
                f"Answer: {ex['label']} | {ex['reason']}\n\n"
            )
        elif email_type == "body":
            prompt += (
                f"Body: {ex['body']}\n"
                f"Answer: {ex['label']} | {ex['reason']}\n\n"
            )
        elif email_type == "combined":
            prompt += (
                f"Sender: {ex['sender']}, Subject: {ex['subject']}, Date: {ex['date']}, Body: {ex['body']}\n"
                f"Answer: {ex['label']} | {ex['reason']}\n\n"
            )

    # Now add the row to classify
    if email_type == "header":
        prompt += (
            f"Sender: {row['sender']}, Subject: {row['subject']}, Date: {row['date']}\n"
            f"Answer:"
        )
    elif email_type == "body":
        prompt += (
            f"Body: {row['body']}\n"
            f"Answer:"
        )
    elif email_type == "combined":
        prompt += (
            f"Sender: {row['sender']}, Subject: {row['subject']}, Date: {row['date']}, Body: {row['body']}\n"
            f"Answer:"
        )

    return prompt

# %%
import time
import pandas as pd
model = genai.GenerativeModel('gemini-2.0-flash')


def analyze_email_few_shot(prompt):
    try:
        # print("respose")
        response = model.generate_content(prompt)
        # time.sleep(2)  # Delay between requests

        result_text = response.text.strip().replace("**Explanation:**", "").replace("**Reason:**", "").replace("*", "").replace("Format: ","")
        print(result_text)

        if "|" in result_text:
            prediction, reason = result_text.split("|", 1)
        else:
            prediction, reason = result_text, "No detailed reason provided."

        # print(prediction)
        # print(reason)

        prediction = prediction.replace("**Prediction:**", "").strip()
        reason = reason.replace("**Explanation:**", "").replace("**Reason:**", "").strip()

        return pd.Series([prediction, reason])

    except Exception as e:
        return pd.Series(["Error", str(e)])

# %%
def process_sample_75_few_shot(file_name, email_type):
    input_path = os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'prompt_data','sample_75_without_labels',file_name)
    # f'/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/{file_name}'
    output_folder = os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'output_daata','fewshot')
    #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/output_daata/fewshot'
    os.makedirs(output_folder, exist_ok=True)

    output_file = file_name.replace('.csv', '_fewshot_predicted.xlsx')
    output_path = os.path.join(output_folder, output_file)

    # Load input data
    df = pd.read_csv(input_path)

    # Apply Gemini to each row using few-shot prompt
    df[['Prediction', 'Reason']] = df.apply(
        lambda row: analyze_email_few_shot(create_few_shot_prompt(row, email_type)),
        axis=1
    )

    # Convert textual label to numeric
    df["prediction_label"] = df["Prediction"].map(lambda x: 1 if x.strip().lower() == "phishing" else 0)

    # Reorder prediction_label
    cols = df.columns.tolist()
    if "Prediction" in cols and "Reason" in cols and "prediction_label" in cols:
        pred_idx = cols.index("Prediction")
        cols.insert(pred_idx + 1, cols.pop(cols.index("prediction_label")))
        df = df[cols]

    # Save to Excel
    df.to_excel(output_path, index=False)
    print(f"✅ Few-shot processed and saved → {output_path}")

# %% [markdown]
# ## Chain of thought

# %%
def create_chain_of_thought_prompt(row, email_type="header"):
    if email_type == "header":
        return f"""
You are a cybersecurity expert specializing in phishing detection.
Carefully review the email header provided and predict whether it is 'Phishing' or 'Legitimate'.

Instructions:
- Analyze sender, receiver, subject, and date briefly.
- Predict if the email is Phishing or Legitimate.
- Directly output in the format given below without any detailed explanation.

Header:
Sender: {row['sender']}
Receiver: {row['receiver']}
Subject: {row['subject']}
Date: {row['date']}
Compare the instructions or requests made in the email with the sender information, subject line, and other header details. If **any part of the instruction seems suspicious, misleading, or abnormal**, classify the email as "Phishing".

You must return only one label: either Phishing or Legitimate. Do not return both.
Output Format:
Phishing or Legitimate | Reason: [Short reason here]
(❗ No need for step-by-step analysis. Only final short prediction and reason.)
"""

    elif email_type == "body":
        return f"""
You are a cybersecurity expert specializing in phishing detection.
Carefully review the email body provided and predict whether it is 'Phishing' or 'Legitimate'.

Instructions:
- Analyze the email body briefly.
- Predict if the email is Phishing or Legitimate.
- Directly output in the format given below without any detailed explanation.

Body:
{row['body']}
Compare the instructions or requests made in the email with the sender information, subject line, and other header details. If **any part of the instruction seems suspicious, misleading, or abnormal**, classify the email as "Phishing".

You must return only one label: either Phishing or Legitimate. Do not return both.
Output Format:
Phishing or Legitimate | Reason: [Short reason here]
(❗ No need for step-by-step analysis. Only final short prediction and reason.)
"""

    elif email_type == "combined":
        return f"""
You are a cybersecurity expert specializing in phishing detection.
Carefully review the full email (header and body) and predict whether it is 'Phishing' or 'Legitimate'.

Instructions:
- Analyze sender, receiver, subject, date, and body briefly.
- Predict if the email is Phishing or Legitimate.
- Directly output in the format given below without any detailed explanation.

Header:
Sender: {row['sender']}
Receiver: {row['receiver']}
Subject: {row['subject']}
Date: {row['date']}

Body:
{row['body']}

Compare the instructions or requests made in the email with the sender information, subject line, and other header details. If **any part of the instruction seems suspicious, misleading, or abnormal**, classify the email as "Phishing".

You must return only one label: either Phishing or Legitimate. Do not return both.
Output Format:
Phishing or Legitimate | Reason: [Short reason here]
(❗ No need for step-by-step analysis. Only final short prediction and reason.)
"""

    else:
        raise ValueError("❌ Invalid email_type passed to prompt generator.")

# %%
# def create_chain_of_thought_prompt(row, email_type="header"):

#     if email_type == "header":
#         return f"""
# You are a cybersecurity expert. Decide if this email header is phishing or legitimate.

# Sender: {row['sender']}
# Receiver: {row['receiver']}
# Subject: {row['subject']}
# Date: {row['date']}

# Answer format: Legitimate or Phishing | Brief Reason
# """

#     elif email_type == "body":
#         return f"""
# You are a cybersecurity expert. Decide if this email body is phishing or legitimate.

# Body: {row['body']}

# Answer format: Legitimate or Phishing | Brief Reason
# """

#     elif email_type == "combined":
#         return f"""
# You're a cybersecurity analyst. Decide if this full email is phishing or legitimate.


# Sender: {row['sender']}
# Receiver: {row['receiver']}
# Subject: {row['subject']}
# Date: {row['date']}
# Body: {row['body']}

# Answer format: Legitimate or Phishing | Brief Reason
# """

#     else:
#         raise ValueError("❌ Invalid email_type passed to prompt generator.")

# %%
def analyze_email_chain_of_thought(prompt):
    try:
        response = model.generate_content(prompt)
        # time.sleep(2)  # Delay between requests

        result_text = response.text.strip().replace("**Explanation:**", "").replace("**Reason:**", "").replace("*", "").replace("Format: ","")
        print(result_text)

        if "|" in result_text:
            prediction, reason = result_text.split("|", 1)
        else:
            prediction, reason = result_text, "No detailed reason provided."

        # print(prediction)
        # print(reason)

        prediction = prediction.replace("**Prediction:**", "").strip()
        reason = reason.replace("**Explanation:**", "").replace("**Reason:**", "").strip()

        return pd.Series([prediction, reason])  # Always returns exactly two elements

    except Exception as e:
        # ❌ If Gemini call fails, return error message for logging or review
        return pd.Series(["Error", str(e)])

# %%
# Loads a sample_75 CSV file, applies CoT prompting, and saves results as Excel
def process_chain_of_thought(file_name, email_type="header"):
    # 🔹 Define paths
    input_path = os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'prompt_data','sample_75_without_labels',file_name)
    #  f'/content/drive/MyDrive/outPut_Folder/gpt_llm/prompt_data/sample_75_without_labels/{file_name}'
    output_folder = os.path.join(path,'001 Submission','All APIs', 'gemini_llm', 'output_daata','chainofthought')
    #  '/content/drive/MyDrive/outPut_Folder/gpt_llm/output_daata/chainofthought'
    os.makedirs(output_folder, exist_ok=True)

    output_file = file_name.replace('.csv', '_cot_predicted.xlsx')
    output_path = os.path.join(output_folder, output_file)

    # 🔹 Load input CSV into DataFrame
    df = pd.read_csv(input_path)

    # 🔹 Generate CoT prompt per email and apply Gemini pro
    df[['Prediction', 'Reason']] = df.apply(
        lambda row: analyze_email_chain_of_thought(create_chain_of_thought_prompt(row, email_type)),
        axis=1
    )

    # 🔹 Map textual prediction to numeric label (1 = phishing, 0 = legitimate)
    df["prediction_label"] = df["Prediction"].apply(
        lambda x: 1 if isinstance(x, str) and "phishing" in x.lower() else 0
    )

    # 🔹 Reorder columns (optional)
    cols = df.columns.tolist()
    if "Prediction" in cols and "Reason" in cols and "prediction_label" in cols:
        pred_idx = cols.index("Prediction")
        cols.insert(pred_idx + 1, cols.pop(cols.index("prediction_label")))
        df = df[cols]

    # 🔹 Save final DataFrame as Excel
    df.to_excel(output_path, index=False)

    # Confirm completion
    print(f"✅ CoT analysis complete for '{email_type}' emails. File saved at: {output_path}")

# %% [markdown]
# # calling the function and showing partial results

# %%
process_sample_75_csv_to_output("header_sample_75_without_label.csv", email_type="header")
process_sample_75_csv_to_output("body_sample_75_without_label.csv", email_type="body")
process_sample_75_csv_to_output("header_body_sample_75_without_label.csv", email_type="combined")
# Out:
# Phishing|Reason: The sender's email address (Young@iworld.de) is suspicious and doesn't match any known legitimate service. The generic subject line "Never agree to be a loser" is also typical of phishing emails, designed to provoke a reaction. The domain `iworld.de` seems unrelated to any common or recognized entity.
# Phishing|The sender's email address looks suspicious and unrelated to the subject line, which is also highly suspicious ("Befriend Jenna Jameson").
# Phishing|The sender's email address (Karmandeep-opengevl@universalnet.psi.br) is suspicious and doesn't appear to be related to CNN.com. The domain 'universalnet.psi.br' has no obvious connection to CNN. The subject line is generic, which is common in phishing attempts.
# Legitimate|Reason: The email appears to be an automated message related to a Subversion (svn) commit within the Apache SpamAssassin project.  The sender, although having an unusual email address, is replying to a mailing list associated with SpamAssassin development ("SpamAssassin Dev <xrh@spamassassin.apache.org>"). The subject line indicates an svn commit, which is typical for software development projects.  The mention of file paths within the SpamAssassin project (e.g., lib/Mail/SpamAssassin/PerMsgStatus.pm) further supports its legitimacy.  Phishing emails rarely relate to specific software development tasks and project file structures.
# Phishing|The sender's email address "externalsep1@loanofficertool.com" appears suspicious and unrelated to the subject "SpecialPricesPharmMoreinfo," which is a common tactic in phishing emails to lure recipients.
# Phishing|The sender's email address (dwthaidomainnamesm@thaidomainnames.com) doesn't seem to match the name "Caroline Aragon".  This discrepancy is a common phishing tactic to disguise the sender's true identity. Also, the date is from 2008, which is suspicious in modern context unless there is a specific reason for it.
# Phishing|The sender's email address (jhorton@thebakercompanies.com) likely does not match the subject of the email ("Replica Watches"). This discrepancy is a strong indicator of phishing, as legitimate businesses usually use email addresses that align with their products or services.
# Phishing|The sender's email address (acidirev_1972@tcwpg.com) is suspicious and doesn't align with CNN.com. Legitimate emails from CNN would likely come from a CNN-owned domain. The random characters and numbers before the @ symbol further suggest a phishing attempt.
# Legitimate|The email originates from the 'issues.apache.org' domain, which is a legitimate domain for Apache projects. The email subject indicates a bug report related to URI processing, which is consistent with the activities of the SpamAssassin project (the recipient).
# Phishing|The sender's email address (orn|dent_1973@musicaedischi.it) is suspicious. It doesn't align with a legitimate CNN email address, which would likely be from a cnn.com domain. The random characters and unfamiliar domain suggest a phishing attempt.
# Phishing|The sender's email address (370jcmiller@flychautauqua.com) is suspicious. It's unlikely a legitimate debt consolidation service would use such an address. The domain "flychautauqua.com" seems unrelated to debt consolidation, further suggesting a phishing attempt. The generic subject line "debt consolidation" is also a common tactic used in phishing emails.
# Phishing|Reason: The sender's email address (rehearsings46@gametea.com) looks suspicious and unrelated to a legitimate sender. The subject line sounds like generic marketing spam, which is a common tactic used in phishing emails.
# Phishing|The sender's email address (`Atchuthan-erbatest@weijgers.nl`) is suspicious and doesn't align with CNN.com. Legitimate news outlets use professional email addresses related to their domain. The random name before the @ symbol and the unfamiliar domain name suggest phishing.
# Phishing|The sender's email address (Scooter-obailat@picklesmaternity.com) has nothing to do with CNN.com and appears to be a random, likely compromised, account. This is a strong indicator of phishing.
# Phishing|Reason: The sender's email address (exited@realskate.com) is suspicious and doesn't seem professional or related to a legitimate business. The subject "Fifth / Sixth month" is vague and could be an attempt to pique curiosity and lure the recipient into opening the email. The overall combination of these factors suggests a phishing attempt.
# Phishing|The sender's email address "uqyrmo@sailing.ie" looks suspicious and doesn't align with a legitimate racing organization. The random characters before "@sailing.ie" are a red flag. Also, the subject "RE: Trial IRC Certificate Application" is vague and could be an attempt to lure the recipient into opening the email.
# Phishing|The sender's email address (Joep-ntorions@picklesmaternity.com) has nothing to do with CNN, which is a major red flag. The domain "picklesmaternity.com" is completely unrelated to CNN. Also, the receiver email (netsearchn@gvc.ceas-challenge.cc) looks like a generic or possibly auto-generated address, which isn't necessarily phishing on its own, but is another factor that increases suspicion given the sender address.
# Phishing|Reason: The sender's email address "Marci-ntelstok@picklesmaternity.com" is suspicious. It doesn't seem to relate to CNN, and the domain "picklesmaternity.com" is likely unrelated to a news organization. This discrepancy strongly suggests phishing.
# Legitimate|Reason: The email appears to be a reply to a technical question on the opensuse.org mailing list. The sender's email address, while from a less common domain (hotpop.com), doesn't immediately raise red flags. The subject is relevant to the mailing list and the date is from 2008, suggesting it's not a recent phishing attempt. Without the email body, it's difficult to be 100% certain, but the header alone doesn't indicate phishing.
# Phishing|Reason: The sender address "cmiqlkx91@hotpop.com" is highly suspicious. It's an unlikely and generic-looking email address on a free email service (hotpop.com), not associated with any legitimate organization, especially not openSUSE. The recipient address being a general openSUSE mailing list further increases the likelihood of it being spam or phishing. The subject line is less of an indicator but could be used to entice users.
# Phishing|The sender's email address (johvdvu-tqrpvc@aaas-alerts.org) looks suspicious and doesn't align with a legitimate email address structure from a reputable organization like AAAS (American Association for the Advancement of Science). The random characters before the @ symbol are a common tactic used in phishing emails to avoid spam filters and mask the true sender.
# Legitimate|Reason: The email appears to be related to the Perl programming language (as indicated by the sender's domain "@perl.org", the subject line referencing a Perl issue, and the presence of "[perl #46011]"). While the recipient address looks somewhat unusual, it might be an automated address for a bug tracker or mailing list. Therefore, there's no immediate red flag indicating phishing.
# Legitimate|Reason: The email appears to be an automated digest from a mailing list at a legitimate academic institution (waikato.ac.nz). The sender address, while unusual, is likely automatically generated by the list management software. The subject line suggests a digest of posts, which is consistent with mailing list behavior. There's no immediate red flag suggesting phishing.
# Legitimate|Reason: This email appears to be an automated message from a source code management system (sourceforge.net) indicating a change/update in a Python project (spambayes). The sender's email address, while unusual, is associated with sourceforge.net, and the recipient is a mailing list at python.org related to that project. The subject line also aligns with typical commit notification emails. There are no immediately obvious red flags that would indicate phishing.
# Phishing|Reason: The sender's email address (`cmiqlkx91@hotpop.com`) looks suspicious and unrelated to Aaron Kulkis or any official communication channel associated with the opensuse project. Using a generic, free email service like hotpop.com is uncommon for legitimate project communication, raising a red flag. While the subject seems related to the opensuse mailing list, the sender address is highly indicative of phishing or spam.
# Phishing|Reason: The subject line ";) Look porno Gallery!!!" is highly suspicious and indicative of spam or phishing attempts. Legitimate emails rarely, if ever, use such suggestive or explicit language, especially in the subject line.
# Legitimate|Reason: The email header appears normal and doesn't contain any obvious red flags typically associated with phishing emails. The sender's email address, while not a common one, appears to be a legitimate domain. The subject is generic but not alarming. The date is also normal. Without the email body, it is hard to be certain, but based on the headers alone, it does not appear to be phishing.
# Phishing|The sender's email address (cmiqlkx91@hotpop.com) looks suspicious and doesn't align with a legitimate communication from or related to OpenSuse. Free email providers like hotpop.com are often used for phishing attempts. Additionally, the random characters in the sender's email address are a red flag.
# Phishing|The sender's email address (verkoeld1978@stfrancis.k12.mn.us) appears to be a compromised or spoofed account at a school, and the subject line "Love consultants recommend herbal products" is a common spam/phishing tactic.
# Phishing|Reason: Several red flags indicate a phishing attempt: The sender's email address (shadiervh97@gillscruisecentre.com) doesn't seem to match the name "Maryellen Costello" and looks suspicious. The subject line "MBA-Degreees not for sale- get it." contains typos and uses a clickbaity tone, typical of spam or phishing emails. The unusual wording of the subject also raises suspicion.
# Phishing|The sender's email address (steins@4000down.com) has nothing to do with CNN.com, which is a strong indicator of phishing.
# Phishing|The sender's email address (xigoing@cityofws.org) appears suspicious. It's an unusual username paired with what looks like a legitimate organization's domain, but legitimate emails typically use a more professional email format (e.g., cara.childs@cityofws.org). The generic subject line "Man's stuff store" also raises suspicion. The date is also very old (2008) which makes it unlikely to be a legitimate current communication.
# Phishing|Reason: The email uses a generic and potentially manipulative subject line ("Change your weakness to power"). The sender's email address (Dannie@archie.dk) doesn't seem to relate to any known legitimate service, and the receiver's email address (user2.15@gvc.ceas-challenge.cc) is unusually formatted. The combination of these factors suggests a phishing attempt.
# Phishing|Reason: The sender's domain "crypt.org" seems suspicious and unrelated to a typical service or known contact. The receiver's email address "oryiufjn@gmail.com" appears randomly generated, further suggesting this is not a legitimate communication. The vague subject line is also characteristic of phishing attempts to lure the recipient into opening the email.
# Legitimate|Reason: The email appears to be from a personal email address and not trying to impersonate a well-known company or service. The subject line is also vague but not alarming, suggesting a genuine inquiry rather than an attempt to trick the receiver. The date also indicates it's a very old email.
# Phishing|The sender's email address `k|bet2005@0166.co.jp` is suspicious and does not appear to be associated with CNN.com. The domain `0166.co.jp` is unusual for a reputable news organization.
# Phishing|The subject line is sexually suggestive and unrelated to any legitimate business purpose, and the sender's email address is suspicious. This is a common tactic used in phishing emails to lure recipients into opening the email or clicking on malicious links.
# Phishing|The subject line "Touch her heart with your new babymaker" is highly suspicious and inappropriate for a professional email. The sender's email address also appears unusual and potentially unrelated to the subject matter.
# Legitimate|Reason: This email header appears to be from a legitimate Apache.org email address related to a bug report. The sender's domain is "@issues.apache.org," and the receiver is "@spamassassin.apache.org," both indicating involvement with the Apache project. The subject line is also consistent with a bug report.
# Phishing|Reason: The subject line "Mega-huge dimension for you!" is highly suspicious and typical of spam or phishing attempts. Legitimate business emails rarely use such sensational and vague language. The combination of a generic email address like "user2.9@gvc.ceas-challenge.cc" with a subject that sounds like spam raises red flags.
# Phishing|Reason: The sender's email address (dwtiscalim@tiscali.it) looks suspicious and unrelated to the subject or a legitimate organization that would be sending quit-smoking advice. The generic subject line is also a common phishing tactic to lure users.
# Phishing|Reason: The sender's email address (Kandace-ukodibeh@victoriaco.com) is unlikely to be the official CNN email address, and appears suspicious. The domain 'victoriaco.com' has no obvious connection to CNN. The fact that the email is trying to mimic a reputable news source (CNN) is another indicator of phishing.
# Phishing|The sender's email address (StaceybearberryRojas@defamer.com) looks suspicious and unrelated to any legitimate service. The subject line also appears to be nonsensical and contains unusual words.
# Phishing|Reason: The sender address "g_nsotzyl@gmx.de" looks suspicious. It's an unusual GMX (a free email provider) address that doesn't obviously relate to "Michael Höller." The subject line also contains grammatical errors ("unsure" instead of "ensure") which is common in phishing emails. These inconsistencies raise red flags. While not conclusive on its own, the combination of these factors makes it likely to be a phishing attempt.
# Legitimate|Reason: The sender address (emailalerts@winnipegfreepress.com) appears to be a legitimate email address from the Winnipeg Free Press. The subject line is also consistent with a news alert. However, without examining the email body, this is only a preliminary assessment. The receiver email address is suspicious as it is obviously a trap/test email account, so somebody at the Winnipeg Free Press may have been testing email sending functionality.
# Phishing|Reason: The sender's email address "cmiqlkx91@hotpop.com" looks suspicious and doesn't appear to be related to a legitimate organization or person associated with OpenSuse. The use of a free email service like "hotpop.com" is a red flag, especially when contacting an official OpenSuse mailing list.
# Phishing|The subject "Answers to erectile dysfunction" is a common spam and phishing tactic to lure recipients with promises of medication or solutions for a sensitive health issue. The generic sender name "Nhan" and the lack of a clear, reputable organization associated with the email further suggest it's likely phishing.
# Legitimate|The sender address KNTV@nbclocal.com appears to be a legitimate NBC email address. The receiver address trapnbc@gvc.ceas-challenge.cc suggests it's part of a security challenge, implying the email is expected and safe for analysis. The date is also quite old (2008), making it unlikely to be a current phishing attempt.
# Phishing|Reason: The sender's email address (ranewc_1999@kamis.pl) is suspicious and unlikely to be the official email address for CNN.com. The domain "kamis.pl" is not associated with CNN.
# Phishing|The sender's email address (anovesic@jasonjones.com) doesn't appear to be related to CNN.com, which is the stated source of the "Daily Top 10". This discrepancy is a strong indicator of phishing.
# Legitimate|Reason: The sender is from a university (@uwaterloo.ca) and the subject refers to a "Spam Challenge", suggesting a research or academic purpose. The receiver address, while unusual, could be a mailing list. This aligns with academic communication, making it more likely to be legitimate.
# Legitimate|Reason: The email appears to be a response to a discussion thread on the opensuse.org mailing list. While the sender's email address (cmiqlkx91@hotpop.com) looks a bit suspicious because it's a free email service and contains random characters, this was much more common in 2008. The receiver is an opensuse mailing list address, and the subject is related to a technical issue, suggesting it's a genuine communication within the openSUSE community. It is unlikely to be phishing, as phishing attacks target individuals with malicious intention. This email appears to be for general discussion.
# Phishing|Reason: The sender's email address (cmiqlkx91@hotpop.com) is highly suspicious. It's an unusual, randomly generated string at a free email provider (hotpop.com). This is not typical for legitimate communication related to openSUSE, which would usually come from an openSUSE domain or a known contributor's address.
# Legitimate|Reason: The email originates from the "issues.apache.org" domain, which is a legitimate domain used by the Apache Foundation for issue tracking. The subject also appears to be related to a specific bug report within an Apache project (SpamAssassin, based on the receiver address). While sender address spoofing is always possible, the presence of a valid Apache domain makes it far more likely to be a legitimate email, especially given the content is related to bug tracking.
# Legitimate|Reason: The sender's email address ends in "@perl.org," which is the legitimate domain for the Perl programming language organization. This suggests it's a legitimate job posting related to Perl.
# Legitimate|The sender address `xycn-vtnhz@perl.org` ends in `perl.org`, which is the legitimate domain for Perl. Emails about Perl jobs sent to a Perl related email address like `necc@perl.org` would be expected and a normal action. The subject line is also consistent with the purpose of the email list.
# Legitimate|Reason: The email appears to be a legitimate newsletter from the Organic Consumers Association, sent through a known email marketing service (Democracy in Action). While the subject line might seem sensationalized, it aligns with the OCA's advocacy topics from that era. There's no immediate red flag pointing to phishing. However, without seeing the email body, this is based solely on the header information provided.
# Legitimate|Reason: The sender address is from the perl.org domain, which is a legitimate domain for Perl-related communication. The subject line, while possibly unsolicited, is related to Perl jobs, consistent with the domain. The date is also a normal date format. There are no immediately obvious red flags.
# Phishing|The sender's email address (`legrand@wxs.nl`) doesn't seem to match the apparent sender name ("bradley dept"). The subject line ("photo Interesting for 7eac07b0ac7489227e7e5bcf767b2dd3") is generic and uses a seemingly random string of characters, which is typical of phishing attempts. The overall structure is suspicious.
# Legitimate|Reason: The sender address `xycn-vtnhz@perl.org` uses the `perl.org` domain, which is likely the legitimate domain for Perl-related communication. While the subdomain `xycn-vtnhz` looks a bit unusual, it doesn't automatically indicate phishing, especially if it's part of an automated mailing system. The subject line is consistent with job postings related to Perl, which is also expected from `perl.org`. Given that this email dates from 2008, subdomain and email security practices were less stringent then than they are today.
# Legitimate|Reason: The email appears to be part of a legitimate mailing list ([spambayes-dev] for a Python project) and the sender's domain (klenner.at) seems plausible. The subject line also seems relevant to a development mailing list. There's no immediately obvious indication of malicious intent from this limited header information.
# Phishing|Reason: The generic subject line " All the excitement all the fun and all the money!" is a common tactic used in phishing emails to lure recipients with promises of unrealistic rewards.  The sender's email address also looks suspicious.
# Phishing|The sender's email address `dwteasm@teas.sk` doesn't seem to relate to the subject of "money back guarantee", and the domain `teas.sk` is suspicious. The subject line itself is also a common tactic used in phishing emails to grab attention. The receiver address `user2.8@gvc.ceas-challenge.cc` also seems suspicious.
# Legitimate|The email appears to be a genuine question posted to a statistics mailing list (r-help) regarding a statistical modeling technique. The sender's address, while a generic Gmail account, isn't inherently suspicious, and the subject matter is relevant to the mailing list. There are no immediately obvious red flags indicating phishing.
# Phishing|Reason: The email address "Earle@cissa-mex.com" is suspicious and doesn't appear to be a legitimate or trustworthy source. The subject line "Make your gf happy" is vague and potentially clickbait, typical of phishing attempts. The receiving email also looks suspicious.
# Legitimate|Reason: The sender's email address ends in "@perl.org," which is the legitimate domain for the Perl programming language organization. This suggests it's a genuine email related to Perl jobs. While subject and content are needed for a definitive assessment, the sender address itself points towards legitimacy.
# Phishing|The sender's name "andrzej janaki" doesn't match the sender's email address "linda.groah@kp.org", which is a red flag. This inconsistency suggests potential spoofing, a common phishing tactic. The generic subject line and unusual receiver address further add to the suspicion.
# Phishing|The sender's email address (arvet1968@shag.dealerspace.com) does not match the purported sender (CNN.com). This discrepancy is a strong indicator of phishing.
# Phishing|The sender's email address (mhunseen@boxingvic.org.au) seems unrelated to the subject line ("We offer you happiness"). The subject line is also vague and enticing, a common tactic in phishing emails to lure victims. The date is also quite old, raising further suspicion.
# Phishing|The sender's email address (rezilatn1993@freemail.selfip.org) is suspicious and does not match the purported sender (CNN.com).  The 'freemail.selfip.org' domain is likely a free or disposable email service, which is a common tactic used in phishing attempts.
# Phishing|The sender's email address (sbogeb_1995@zamilsteel.com) does not appear to be related to CNN.com. Legitimate CNN emails would likely come from a CNN domain. The unusual username format (sbogeb_1995) also raises suspicion.
# Phishing|Reason: The sender's email address ("BRalpine@packbell.net") is suspicious and doesn't align with the subject of online prescriptions. The subject line itself promises prescription-free medication, which is a common tactic used in phishing emails related to pharmaceuticals. The generic subject line "ID:19346" also adds to the suspicion.
# Phishing|Reason: The sender's email address (RomeoregistrarNoble@geneontology.org) is unlikely to be associated with Bvlgari watches. The subject line ("Ravishing Bvlgari watches at Replica Classics") is also a common tactic used in phishing emails to lure recipients with enticing offers. The generic receiver address "ser@gvc.ceas-challenge.cc" is another red flag. The email was also sent in 2008, which is also suspicious, though not conclusive.
# Phishing|The sender's email address (ppcwedbyff@gmail.com) is a generic Gmail address and doesn't match any known legitimate source for Python development summaries. The mismatch between the date in the subject (April 1-15, 2007) and the actual date of the email (August 5, 2008) is also suspicious.
# Phishing|Reason: The sender's email address (akstcallawasayamnsdgs@allawasaya.com) looks suspicious and unrelated to the name "Pam Abrams" and the subject "Splendid Health Joy" is generic and potentially a lure.
# ✅ Processed: header_sample_75_without_label.csv → Saved to /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/output_daata/zeroshot/header_sample_75_without_label_predicted.xlsx
# Phishing|The email contains generic, attention-grabbing subject lines and promises unrealistic results related to physical attributes, which is a common tactic used in phishing and spam emails. The presence of a suspicious URL ("whitedone.com") without context further indicates malicious intent. The unrelated text at the end is also suspicious.
# Phishing|Reason: The email contains unsolicited and sexually suggestive content with a suspicious link to an unrelated domain ("brightmade.com"). This is a common tactic used in phishing emails to lure recipients to potentially malicious websites.
# Legitimate|The email body appears to be a genuine CNN daily news update. It includes a list of top videos and stories with corresponding CNN URLs. The email also contains standard CNN copyright information, contact information, and unsubscribe links, which are typical of legitimate email newsletters. While the date is from 2008, the structure and content are consistent with how CNN distributed news updates at that time.
# Legitimate|This email appears to be part of a discussion within the Apache SpamAssassin project about updating the list of valid top-level domains (TLDs). The email includes a technical discussion, code modifications, and links to the Apache Subversion repository, which are all indicative of a legitimate software development project. The sender's email address (@apache.org) also supports this classification.
# Phishing|The URL provided is suspicious. It uses a URL shortening service (blu.livefilestore.com, seemingly associated with Microsoft OneDrive, but abused here) to hide the actual destination, which is unlikely to be a legitimate website for a company offering "FastShippingCustomerSupport." The random characters in the URL also raise suspicion. Real companies use easily recognizable domains and paths.
# Phishing|Reason: The text is nonsensical and uses random characters, likely an attempt to bypass spam filters. Legitimate emails wouldn't contain such garbled content.
# Phishing|The email is advertising counterfeit goods (replica watches), which is a common tactic used by phishing scams. Legitimate businesses typically don't offer or promote illegal activities.
# Legitimate|Reason: This email looks like a genuine CNN daily top 10 email. The links appear to be CNN URLs, the format matches what a CNN email might look like, and it includes unsubscribe links and copyright information. There is nothing overtly suspicious about the email body itself. Also, the date in the body is from 2008, so it is most likely an archived email, not a recent phishing attempt.
# Legitimate|Reason: The email originates from a known and reputable source (apache.org), uses a standard bug tracking system notification format, and doesn't request any sensitive information or contain suspicious links outside the apache.org domain. It's simply an automated notification about a bug update.
# Legitimate|Reason: The email appears to be a legitimate CNN Daily Top 10 email from 2008. The links provided seem to direct to CNN.com and the email includes standard CNN disclaimers, copyright information, and unsubscribe links, which are all indicators of a legitimate email communication from CNN. The date is quite old, but this alone does not make it phishing.
# Phishing|The email makes unrealistic promises of debt elimination without affecting credit, a common tactic used in debt relief scams. The vague language and emphasis on avoiding traditional methods like bankruptcy or consolidation are red flags. The website URL "freshplateworks.com" also appears suspicious and lacks credibility for a legitimate debt relief service.
# Phishing|Reason: The email is very short and generic, offering Adobe Creative Suite 3 (an old version) with a suspicious link "oemmerchant.com". This is a common tactic used in phishing emails to lure users to malicious websites that might host malware or steal their credentials. The link itself is untrustworthy and likely not an authorized Adobe reseller. A legitimate email from Adobe or an authorized retailer would be more detailed, personalized, and link to the official Adobe website.
# Legitimate|The email presents itself as a CNN Daily Top 10 email from 2008. The links appear to point to CNN domains, and the email includes standard copyright and unsubscribe information consistent with legitimate email newsletters.
# Legitimate| The email provides links to CNN.com and includes standard information such as CNN's address, copyright notice, privacy guidelines, and unsubscribe links. It also states how the recipient agreed to receive the email. All these factors point to a legitimate email from CNN, especially given the date it references (August 1, 2008). Phishing emails rarely contain this level of legitimate-looking detail.
# Phishing|Reason: The email makes outlandish claims about increasing size and sexual desire with no scientific basis, uses a suspicious link ("pacelike.com"), and lacks credibility or identifiable sender information, all characteristic of spam and potentially malicious phishing attempts.
# Legitimate|The email chain shows a genuine request for a Trial IRC Certificate and subsequent communication. The replies are consistent with a business interaction regarding an application. The details provided seem plausible for the context of sailing certificates and the presence of a MailWall gateway adds to the legitimacy.
# Legitimate|The email appears to be a genuine CNN Daily Top 10 email from 2008. The links are to cnn.com, the formatting is consistent with email newsletters, and it includes standard unsubscribe and privacy policy links. The older date helps confirm it is likely an archived or historical email, not a current phishing attempt.
# Legitimate|The email appears to be a legitimate CNN Daily Top 10 email from 2008. The links point to CNN.com domains, the content is consistent with news headlines, and the email includes standard CNN copyright and unsubscribe information. While historical, there's no indication of malicious intent or data harvesting.
# Legitimate|This email appears to be a forwarded discussion from the TuxOnIce-users mailing list. The content discusses technical issues related to the TuxOnIce hibernation software, with multiple participants and quoted replies, which is typical of mailing list conversations. There is no request for personal information or suspicious links, and the email includes standard mailing list footers.
# Legitimate|This email appears to be a forwarded message from a mailing list (Wekalist) related to the Weka machine learning workbench. The content consists of discussions, questions, and answers among list members. There are no obvious indicators of phishing, such as requests for sensitive information, suspicious links, or unusual urgency. The email headers and footers are consistent with a mailing list format.
# Legitimate|Reason: The email appears to be a digest from ScienceNOW, a legitimate science news source affiliated with the American Association for the Advancement of Science (AAAS). The links provided seem to point to sciencemag.org, which is a valid domain for Science magazine and related publications. The email includes options to unsubscribe and contact information, further supporting its legitimacy. There are no obvious red flags like suspicious links or urgent requests for personal information.
# Legitimate|Reason
#
# This email appears to be an automated bug report generated by a perlbug tool. The content is highly technical, including configuration details, code snippets, and environment information related to Perl. It's unlikely a phisher would craft such a detailed and specific email. The email includes information that looks like standard output from a system and specific commands related to a perl installation.
# Legitimate|Reason: This email appears to be an automated message from a mailing list server (likely Mailman, given the URLs). It provides standard information about how to subscribe, unsubscribe, contact the list administrator, and includes a table of contents for the day's topics. The email addresses, while obfuscated with random characters before the "@" symbol, are consistent with a mailing list system and are from the waikato.ac.nz domain, a legitimate academic institution. There are no obvious red flags like requests for personal information or suspicious links.
# Legitimate|This email appears to be an automated notification from a source code management system (CVS) related to the Spambayes project. The content shows code changes and includes details typical of such notifications. The presence of a mailing list footer further supports its legitimacy. There are no requests for personal information, links to suspicious websites, or other common phishing indicators.
# Legitimate|The email discusses a technical problem related to disk space and the `du` command, which is consistent with a technical discussion among system administrators or developers. There are no red flags like requests for sensitive information, suspicious links, or urgent deadlines. It appears to be a genuine question about a Linux command.
# Phishing|Reason: The email body is short, generic, and uses trending topics (Demi Moore) to lure users to a potentially malicious site. The vague call to action "Go to site!" and the inclusion of random, short alphanumeric strings as hashtags are typical tactics used in phishing emails to obfuscate the true nature of the link and avoid detection. The lack of personalization and context further suggests a phishing attempt.
# Phishing|Reason: The subject matter (celebrity pornography) and the suspicious URL (somateco.com.br/folderz/ready.php) are both highly indicative of a phishing attempt designed to lure users into clicking a malicious link.
# Legitimate|Reason: This email is a part of a technical discussion about Linux security. It doesn't ask for personal information, request to click any links, or exhibit any other common phishing tactics. It is a genuine discussion.
# Phishing|Reason: The subject matter (sexual content) and the generic, suspicious-looking URL ("shinemade.com") are both red flags indicating a high likelihood of phishing or spam. Legitimate sources rarely use such clickbait titles and unfamiliar domains.
# Phishing|Reason: Offers diplomas without coursework or exams, guarantees acceptance, and emphasizes confidentiality. This is a common tactic used in diploma mills, which are fraudulent schemes. The poor grammar and formatting also raise red flags.
# Legitimate|Reason: The email appears to be a legitimate CNN daily top 10 email from 2008. The links provided seem to direct to CNN.com. The email includes CNN's address and copyright information, along with links to CNN's feedback, privacy guidelines, and subscription management pages. The overall format and content align with what one might expect from a legitimate news email. Also, note the date of the email, it is very old.
# Phishing|The email uses generic language ("Largest selection of medication products," "best online chemist service") and contains a suspicious list of seemingly random words at the bottom. This combination is indicative of a phishing attempt trying to lure users into purchasing medication from an illegitimate source or clicking on a malicious link. The random words could be an attempt to bypass spam filters or be indicative of the content being generated using automated and unreliable methods.
# Phishing|Reason: The email body contains generic, sensational claims about improving one's "intimate life" with vague promises and includes a suspicious-looking URL ("dearbright.com"). This is a classic tactic used in phishing emails to lure recipients into clicking the link, which could lead to malware or a phishing site designed to steal personal information. The unrelated text about bands and the SEC Act suggests the email body was assembled haphazardly, possibly from unrelated sources, further indicating it's likely a phishing attempt.
# Legitimate|The email body appears to be a technical discussion, likely from a mailing list or forum related to the Perl programming language. It discusses a specific behavior in Perl code and proposes a workaround. There are no red flags such as requests for personal information, suspicious links, or urgent calls to action, so it's likely a legitimate technical discussion. The presence of a signature at the end ("Hugo") further supports this classification.
# Legitimate|Reason: This email appears to be a legitimate inquiry from a bookstore looking for information about a specific book. It provides detailed information about the book, the customer's request, and the bookstore's contact information, including a physical address and phone number. There are no red flags, such as urgent requests for personal information, suspicious links, or grammatical errors, that would suggest a phishing attempt. The email signature also includes the bookstore's name, address, and contact information, which adds to its credibility.
# Legitimate|The email provides links that appear to direct to CNN.com, which is consistent with a news email. The content is news-related, and it includes standard disclaimers, copyright information, and unsubscribe links that are expected from a legitimate email newsletter. Also, the sender's email address ends in "cnn.com", which is a good indicator of legitimacy.
# Phishing|The email contains a generic, sexually suggestive subject line and a suspicious, shortened URL that likely leads to a malicious website. This is a common tactic used in phishing scams.
# Phishing|Reason: The email body is extremely short, generic, and uses a vague claim ("Doctors recommended source") without specifying any brand or product. The call to action "Click here!" is also generic and lacks context, making it suspicious and indicative of a phishing attempt. There is a complete lack of personalization or specific information, which is unusual for legitimate marketing emails.
# Legitimate|Reason: This email appears to be an automated notification from the Apache SpamAssassin bug tracking system. The email format is consistent with bug tracking systems, detailing changes to a specific bug report (ID 5780) and the reason for the notification (assignee or watcher). The content references specific bugs, branches, and vote requests, all of which are typical within open-source project workflows. The email originates from what appears to be a bug tracking system's address, and it does not request any sensitive information or prompt suspicious actions.
# Phishing|Reason: The email uses vague and sensational language ("increasing formula," "stop dreaming away") and links to a suspicious-looking URL ("milddear.com") without any context of a reputable company or service. The unrelated text at the end also suggests it was pieced together haphazardly, a common tactic in phishing emails.
# Legitimate|Reason: This email promotes a product (anti-smoking patch) and doesn't contain any elements typically associated with phishing attempts such as requests for personal information, urgent calls to action, or suspicious links. It appears to be a marketing email.
# Legitimate|Reason:This email body appears to be a legitimate email from CNN. It contains news headlines and links to CNN.com. It also includes standard information like copyright notices, contact information, and unsubscribe links, all of which are consistent with legitimate email newsletters. The links, although shortened, appear to direct to CNN domains when inspected.
# Phishing|The email body contains nonsensical and seemingly random words and phrases. This is a common tactic used in phishing emails to bypass spam filters that look for specific keywords related to scams. The lack of a clear topic or request, combined with the bizarre language, strongly suggests a phishing attempt.
# Legitimate|This email appears to be a technical query related to the CRM114 spam filter software. It details a user's experience setting up and troubleshooting the software within the KMail email client. The inclusion of configuration details, command-line examples, and mailing list information related to the CRM114 project indicates a genuine technical issue rather than a phishing attempt. The GMX advertisement at the end seems to be a standard footer for a free email account and doesn't raise suspicion. The inclusion of the SourceForge mailing list footer further supports the email's legitimacy.
# Legitimate|Reason: This looks like a legitimate email alert from the Winnipeg Free Press. It contains standard elements of a newsletter such as news headlines, links to different sections, copyright information, contact information, a privacy policy, and an unsubscribe link. The date (August 5, 2008) is also consistent with the content. There's no indication of suspicious links or requests for personal information.
# Legitimate|This email is a discussion about operating system security and philosophies. It does not attempt to trick the recipient into providing personal information, clicking malicious links, or downloading harmful files. It appears to be part of a normal conversation.
# Phishing|The email body uses sensational and sexually suggestive language ("schlub," "9 inch tool") and a suspicious, likely unrelated, website link ("milddone.com"). This is a common tactic of phishing emails to lure users into clicking malicious links.
# Legitimate|Reason: This email appears to be an automated newsletter from a news source (NBC11.com). It contains news stories, photo galleries, and video links. There are no requests for personal information or suspicious links, and it includes an unsubscribe option, all of which are characteristics of legitimate newsletters. The presence of advertising and a privacy policy further reinforces its legitimacy. The date of 2008 indicates that the email is likely from an archived source.
# Legitimate|The email appears to be a genuine CNN Daily Top 10 email from August 1, 2008. It contains news headlines and video links, formatted in a way that is consistent with legitimate email newsletters. The links point to CNN.com domains, and the email includes standard disclaimers and unsubscribe information. There are no obvious signs of phishing, such as requests for personal information or suspicious links.
# Legitimate|The email appears to be a genuine CNN.com Daily Top 10 email. It includes news headlines and video links that were relevant on the specified date (August 1, 2008). The links point to CNN domains, and the email includes standard CNN disclaimers, copyright information, and unsubscribe links. While the date is old, it doesn't automatically make it phishing; it could be an archived email.
# Legitimate|Reason: The email announces a legitimate academic event (CEAS Live Spam Challenge). It provides details about the competition, key dates, contact information, and organizers with their affiliations and URLs. The email address information@ceas.cc and the URLs to IBM and the University of Waterloo are consistent with a genuine announcement. Also the ceas.cc domain looks legitimate. The presence of mailing list information at the end further suggests a legitimate automated announcement. There are no obvious red flags like urgent requests for personal information, suspicious links, or grammatical errors.
# Legitimate|This email appears to be a genuine technical discussion between colleagues, likely within an IT or development team. It revolves around a specific problem encountered while using Linux commands and seeks advice on how to achieve the desired result. There are no red flags such as requests for sensitive information, suspicious links, or urgent calls to action.
# Legitimate|This appears to be a snippet of a genuine email thread discussing software quality and personal experiences. There are no suspicious links, requests for personal information, or other typical phishing indicators. The content seems to be a real conversation between individuals.
# Legitimate|Reason: This email originates from a bug tracking system related to Apache SpamAssassin, a well-known and legitimate open-source project. The email content discusses a specific bug report (5813) and refers to another bug report (5780). It also mentions code reviews and voting, all standard practices in software development. The email address wrzzpv@sidney.com, while unusual, could be a legitimate developer email. The "You are receiving this mail because..." section is typical of bug tracking systems. There are no red flags or requests for sensitive information that would indicate phishing.
# Legitimate|Reason: The email contains information about a Perl developer job, including location, description, required skills, desired skills, and URLs for more information and contact. The URLs point to perl.org and mimox.com, which are both likely legitimate websites. The email also provides instructions for subscribing and unsubscribing from the mailing list, which is typical of legitimate email lists. The level of detail is unlike a generic phishing email.
# Legitimate|The email appears to be an automated job posting from a perl.org mailing list. The URLs for both the job and the company (BBC) seem legitimate based on cursory inspection. While old (2008), that doesn't automatically make it phishing. The unsubscribe and subscribe links also point to perl.org.
# Legitimate|This email appears to be a newsletter from the Organic Consumers Association (OCA). It contains relevant information about organic food, health, and environmental issues. It also includes links to their website and ways to subscribe/unsubscribe. While some of the links might lead to donation pages, the content itself isn't inherently malicious or designed to steal personal information. The links provided appear to relate to the content discussed. The provided contact information adds to the legitimacy.
# Legitimate|Reason: The email seems to be an automated job posting from a legitimate source (jobs.perl.org). The email includes details about the job, the company (Epsilon), required skills, and a link to the company's website. The links provided go to perl.org and epsilon.com. There is nothing obviously suspicious about the email content or sender information, so it is most likely a legitimate job posting. The formatting is typical of older automated postings.
# Phishing|Reason: The email contains a sensationalized subject line ("Nicole Kidman Shocking photo!!!") and a generic call to action ("Go to the site") with a suspicious and random looking url ("WQduzYa #CuXrWOz"). This is a common tactic used in phishing emails to lure users to malicious websites.
# Legitimate|The email appears to be a job posting from a Perl job board. It provides details about the job, company, location, and required skills. The email also includes links to the company's website (dbds.com) and the job posting on the Perl job board (jobs.perl.org). While the email is quite old (2008), the presence of legitimate URLs and the lack of any request for sensitive information suggest that it's a legitimate job posting announcement rather than a phishing attempt. The instructions for subscribing and unsubscribing from the mailing list also support this.
# ...
#    Suspicious Date: While not a definitive indicator, the date is rather old (2008) which raises suspicion, especially if the content is nonsensical.
#
# These characteristics strongly suggest that the email is a phishing attempt designed to either deliver malware or trick the recipient into taking a malicious action.
# Legitimate|The email appears to be a genuine question from a user of the crm114 software seeking help with their setup. The sender's email address, while not immediately recognizable, isn't inherently suspicious, and the content aligns with the purpose of the crm114-announce mailing list (discussion and announcements related to the crm114 software). There are no red flags like requests for personal information or suspicious links. The GMX signature at the end of the email is a common email provider.
# Legitimate|Reason: The email is from a known news source (Winnipeg Free Press), the sender address matches the domain, and the subject line is consistent with news alerts. The content of the email links to a news story which was a real news event at the time. The email also includes unsubscribe information. All these factors suggest the email is legitimate.
# Legitimate|The email is a response in an openSUSE mailing list, discussing security concerns and comparing Windows and Linux operating systems. The content is relevant to the mailing list's topic and doesn't contain any suspicious links or requests for sensitive information. While the sender's email address is from "hotpop.com", this doesn't automatically indicate phishing, especially in older emails.
# Phishing|The email has a suspicious subject line ("Answers to erectile dysfunction") and includes a link to a website ("milddone.com") promising unrealistic results ("9 inch tool"). This is a common tactic used in phishing emails to lure recipients into clicking malicious links or providing personal information. The sender's name also appears generic and doesn't inspire trust.
# Legitimate|Reason: The email appears to be a genuine newsletter from NBC11.com, containing news stories and links back to their website. There are no obvious phishing attempts, such as requests for personal information or suspicious links. The presence of an unsubscribe link and standard copyright information further supports its legitimacy.
# Legitimate|The email purports to be a daily top 10 from CNN. The links provided seem to link to CNN properties and the bottom of the email contains the typical unsubscription verbiage as well as a copyright from CNN. The sender email address is suspicious but not enough to discount the entire email as a phishing attempt.
# Legitimate|The email appears to be a legitimate daily top 10 email from CNN. The links provided seem to lead to cnn.com and the email includes standard disclaimers, copyright information, and unsubscribe links, which are expected in legitimate emails from established news organizations.
# Legitimate|The email announces a legitimate event (CEAS Live Spam Challenge). While the sender's email address `zixgfqei@uwaterloo.ca` is unusual, the body references a known conference (CEAS), provides a link to the CEAS website (ceas.cc), and lists organizers with their affiliations (IBM Research, University of Waterloo) and contact information. The dates mentioned are in the past, which is somewhat unusual, but the email itself does not attempt to solicit personal information, request money, or install software. Also, it appears this was sent to a mailing list specifically for this type of announcement.
# Legitimate|The email appears to be part of a technical discussion on an openSUSE mailing list. The content discusses a specific problem related to disk usage, and the sender provides a technical explanation. There are no links or requests for personal information. The "hotpop.com" domain is a free email provider, which might raise a flag in some contexts, but in 2008, it was more common for people to use such services. The rest of the email does not show any other signs of phishing.
# Legitimate|Reason: The email appears to be part of a legitimate discussion thread on the openSUSE mailing list. The content is a reply to previous emails, discussing personal experiences and software versions. There are no red flags like suspicious links, requests for personal information, or urgent calls to action. The sender and receiver domains are consistent with the topic of the email.
# Legitimate|Reason: The email comes from a legitimate Apache.org domain, references a bug report within their issue tracker, and contains information related to the bug's status and potential dependencies on other bugs. The email's content aligns with standard notifications from issue tracking systems like Bugzilla. There are no requests for sensitive information or other red flags associated with phishing attempts.
# Legitimate|Reason: The email originates from "@perl.org," a legitimate domain for Perl-related activities. It advertises a Perl developer job, a common and expected topic for a Perl-related mailing list. The email also includes standard subscription/unsubscription instructions and links to jobs.perl.org, further reinforcing its legitimacy. Although the email is from 2008, its contents and structure are consistent with a legitimate job posting announcement from a Perl jobs mailing list.
# Legitimate|The email originates from a perl.org address, is related to job postings as the subject and body suggest, and contains unsubscribe information. The links provided seem to point to legitimate job posting resources, and the body contains details expected in a job posting, like company name, location, pay rate, and required skills. Although the email is from 2008, this isn't necessarily an indicator of phishing. All evidence points to it being a legitimate job posting announcement.
# Legitimate|The email comes from a known organization (Organic Consumers Association) using a legitimate email address (oca@mail.democracyinaction.org). The content is consistent with the organization's mission and does not contain any obvious phishing attempts like requests for personal information or suspicious links. The unsubscribe links also appear legitimate.
# Legitimate|The email appears to be a legitimate job posting from the Perl Jobs mailing list. The sender's domain (@perl.org) matches the list's domain. It provides a real job description, company name (Epsilon), location, and contact information links pointing back to the perl.org domain. The unsubscribe information is also consistent with a mailing list. There are no obvious red flags or attempts to solicit personal information beyond what's expected in a job application.
# Phishing|The sender's email address (legrand@wxs.nl) is suspicious and doesn't seem related to any known legitimate service or person. The subject line is generic and uses a hexadecimal string, which is common in phishing emails. The body is short, contains a sensational claim ("Nicole Kidman Shocking photo!!!"), and urges the recipient to "Go to the site" without providing a clear link or explanation of what the site is. The random strings of characters "#CuXrWOz" and "WQduzYa" are also suspicious. These are all red flags indicating a phishing attempt.
# Legitimate|The email appears to be a legitimate job posting from the perl.org domain, which is a well-known and trusted source for Perl-related information. The email provides details about the job, company, and contact information, all of which seem reasonable. The URLs provided also appear consistent with the information given. There's no obvious attempt to trick the reader into revealing sensitive information.
# Legitimate|Reason: This email appears to be a genuine query to the spambayes-dev mailing list regarding false positives. The sender seems to be having issues with spambayes incorrectly classifying voicemail notifications as spam and is asking for assistance. The sender's description of their problem and the context of the mailing list suggest a legitimate communication. There are no red flags indicating a phishing attempt, such as requests for sensitive information or suspicious links.
# Phishing|The email exhibits several characteristics typical of phishing attempts: a vague and overly enthusiastic subject line ("All the excitement all the fun and all the money!"), generic greeting and promises of easy money, unsolicited offer, and a suspicious link (casinojackpotsdeals.com). The sender's email address (dtkress@emdas.com) doesn't appear to be related to any reputable casino or gambling organization, further increasing suspicion. The overall tone and content are characteristic of spam and phishing emails designed to lure unsuspecting users.
# Phishing|The sender's email address (dwteasm@teas.sk) looks suspicious and unrelated to any legitimate anti-smoking product. The subject line ("Money back guarantee to ensure results!") is a common tactic used in spam emails. The generic and unsolicited nature of the email body, promoting a product with "guaranteed results," is also indicative of phishing or spam. The formatting is poor, which is another common trait of these types of emails.
# Legitimate|Reason: This email appears to be a genuine request for statistical advice on the R-help mailing list. The content is related to statistical modeling, and the sender is asking for help with a specific problem. The email is well-structured, and there are no obvious red flags (such as suspicious links or requests for personal information) that would indicate phishing. The sender's email address, while a Gmail address, doesn't automatically indicate phishing, especially when posted on a public forum where anonymity is more common. The inclusion of standard mailing list footer information further supports its legitimacy.
# Phishing|Reason: The email exhibits several red flags indicative of phishing: a generic subject line ("Make your gf happy") designed to lure recipients, a body containing sensational and improbable claims ("hottest girls will start shooting rapt glances at your groin!"), a suspicious URL ("dearcan.com"), and an irrelevant and abruptly inserted paragraph about the United Nations. These characteristics suggest the email is an attempt to deceive the recipient into clicking a malicious link.
# Legitimate|The email originates from a perl.org email address, which is the official domain for the Perl programming language community. It promotes a job posting on jobs.perl.org, a legitimate job board for Perl-related positions. The email provides unsubscribe instructions and contact information, standard practice for legitimate mailing lists. The job description seems plausible for a Perl developer role. The sender address and the link in the email body both align with the perl.org domain. While the body has some formatting issues, that does not definitively make it phishing, it might just mean the email was old or the posting was copied over without proper formatting.
# Phishing|The email is unsolicited, contains a generic subject, and has a vague and suspicious body promoting "medication safe and effective" with a generic call to action. The sender's email address, while appearing legitimate (kp.org), could be spoofed. The combination of these factors suggests a phishing attempt to lure the recipient to a potentially malicious website.
# Legitimate|The email appears to be a legitimate CNN Daily Top 10 email. The links provided appear to direct to CNN.com. The email provides options to manage email settings and unsubscribe. The sender's domain, although suspicious, is related to dealerspace.com which may be used for mass emails or marketing campaigns, and the email content is consistent with news headlines.
# Phishing|The email is from an unusual sender address, the subject is vague and enticing, and the body contains generic claims about providing medications, followed by seemingly random words at the end, which is a common tactic used by spammers.
# Legitimate|The email appears to be a genuine daily top 10 email from CNN.com. It includes relevant links and URLs related to CNN and its services. The links in the email seem to direct to the actual CNN website. Also, the email includes standard footers seen in legitimate emails, such as copyright information, contact information, and unsubscribe links.
# Legitimate|The email appears to be a legitimate CNN.com Daily Top 10 email. The sender's domain, "zamilsteel.com," is unusual, but the links in the body all point to CNN.com, and the email includes standard disclaimers, copyright information, and unsubscribe links that are consistent with legitimate email newsletters.
# Phishing|Reason: The email promotes prescription drugs without a prescription, offers express delivery and secure checkout via credit card, and has a suspicious sender email address ("BRalpine@packbell.net") and website URL ("www.outgoeffmedical.com"). These are common tactics used in phishing scams related to pharmaceuticals.
# Phishing|The email exhibits several red flags characteristic of phishing or spam:
#
# 1.  Suspicious Sender Address: While the domain `geneontology.org` might be legitimate, the "RomeoregistrarNoble" part of the email address looks nonsensical and is often used in spam or phishing emails to impersonate someone.
# 2.  Generic Recipient Address: The recipient address "ser@gvc.ceas-challenge.cc" appears to be a catch-all address for a challenge, meaning the sender likely blasted this email to many addresses, a common tactic of spammers and phishers.
# 3.  Subject Line: The subject "Ravishing Bvlgari watches at Replica Classics" is typical of spam advertising counterfeit goods.
# 4.  Body Content: The body promotes "replica watches, pens, bags" and "cheap luxury gifts," clearly indicating the sale of counterfeit goods.
# 5.  Suspicious Link: The URL `http://minimsoyawl.com/` is likely a shortened or obfuscated link to a website selling counterfeit goods, or worse, a site designed to steal personal information or install malware. The domain name itself appears unrelated to watches or luxury goods.
# 6. Date: The email being from 2008 is another red flag, as it's unlikely to be relevant or legitimate after such a long time.
# Legitimate|The email appears to be a genuine summary of Python-Dev mailing list activity from April 1-15, 2007. The content discusses technical topics related to Python development, such as SSL tests, subprocess termination, buffer protocols, and various bug fixes and proposals. The email includes detailed information about contributing threads and references specific bug reports and PEPs (Python Enhancement Proposals). The sender, Calvin Spealman, may be a community member compiling these summaries. While the sender's email address "ppcwedbyff@gmail.com" is slightly unusual, it is not inherently indicative of phishing, and the content itself seems legitimate. The inclusion of a blog link and the standard Python-Dev mailing list footer further support the email's authenticity. There's no call to action requesting personal information or directing the recipient to a suspicious website. Given this context, it is likely a legitimate email from a contributor to the Python community.
# Phishing|Reason: The sender's email address (akstcallawasayamnsdgs@allawasaya.com) is suspicious and doesn't match the apparent subject of "Splendid Health Joy." The link to a "spaces.live.com" blog is also a common tactic used in phishing emails to redirect users to malicious websites. The vague subject line and generic greeting/signature further increase suspicion. The mention of "Extraordinary Medicinal Options" also suggests potential spam or a scam.
# ✅ Processed: header_body_sample_75_without_label.csv → Saved to /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/output_daata/zeroshot/header_body_sample_75_without_label_predicted.xlsx

# %%
process_sample_75_few_shot("header_sample_75_without_label.csv", "header")
process_sample_75_few_shot("body_sample_75_without_label.csv", "body")
process_sample_75_few_shot("header_body_sample_75_without_label.csv", "combined")
# Out:
# Phishing | The sender's email address is unusual, and the subject line is suspicious.
# Phishing | The sender's email address is suspicious and the subject is inappropriate.
# Phishing | The sender's email is from an unusual domain and the subject is generic.
# Legitimate | Seems like a system-generated email regarding a software commit.
# Phishing | The sender's email is suspicious and subject is unrelated.
# Phishing | The sender's email address looks suspicious and the subject line is generic.
# Phishing | The sender is selling replica watches which is likely a scam.
# Phishing | The sender's email address looks suspicious.
# Legitimate | It’s from a known source related to software development.
# Phishing | The sender's email address is not from CNN.
# Phishing | The sender's email address is unusual and the subject is generic.
# Phishing | The sender's email address appears to be random and the subject is generic.
# Phishing | The sender's email address is not related to CNN.
# Phishing | The sender's email is suspicious and the domain name is unrelated to CNN.
# Legitimate | The email appears to be from a known sender with a normal subject.
# Legitimate | The email appears to be a reply in a legitimate context.
# Phishing | The sender's email address looks suspicious and unrelated to CNN.
# Legitimate | Email is from CNN a known source.
# Legitimate | The email appears to be part of a technical discussion thread.
# Legitimate | The email appears to be a forwarded discussion from a public mailing list.
# Legitimate | It seems like an alert from a scientific organization.
# Legitimate | The sender's email looks like a system generated message related to software development.
# Legitimate | It appears to be an automated message from a university domain.
# Phishing | The sender's email address appears to be random and the subject is unusual.
# Legitimate | Email from a non-urgent email platform on a technical query.
# Phishing | The email has a suspicious subject line.
# Legitimate | The email appears to be a regular order confirmation email.
# Legitimate | The sender's email address seems personal, and the subject relates to an open-source project discussion.
# Phishing | The sender's email address is not professional and the subject is suspicious.
# Phishing | The sender's email address is suspicious and the subject is irrelevant.
# Legitimate | It's a daily email from a known source.
# Phishing | The sender's email address looks suspicious and the subject is vague.
# Phishing | The subject line is suspicious and generic.
# Legitimate | The email appears to be a response to a technical question.
# Legitimate | It's from a personal email address with a generic subject.
# Phishing | The sender's email address is suspicious and the subject is generic.
# Phishing | The subject matter is inappropriate and unsolicited.
# Phishing | The subject line is inappropriate and suggestive, indicating a high probability of spam or phishing.
# Legitimate | It appears to be an automated email from a bug tracking system.
# Phishing | The subject line is suspicious and overly enthusiastic.
# Phishing | The sender's email address is suspicious and the subject is generic.
# Phishing | The sender's email address looks suspicious.
# Phishing | The sender's email address is suspicious, and the subject line contains unusual words.
# Legitimate | The email is from a mailing list and appears to be a standard announcement.
# Legitimate | News alert from a known news source.
# Legitimate | The email appears to be a reply in an email thread.
# Phishing | The subject is related to a common spam topic.
# Legitimate | It's a newsletter from a trusted local news source.
# Phishing | The sender's email address looks suspicious and generic.
# Legitimate | It's a daily top 10 from CNN.
# Legitimate | It's from a university email address and references an academic event.
# Legitimate | Appears to be a standard email thread.
# Legitimate | It appears to be a response in an open-source community discussion.
# Legitimate | It's a notification from a known open-source project.
# Legitimate | It’s a job posting from a perl jobs mailing list.
# Legitimate | Email is from a perl.org, likely a job posting.
# Legitimate | It's a newsletter from a known organization.
# Phishing | The sender's email address is unusual and the subject contains a generic job posting.
# Phishing | The sender's email is suspicious and the subject is generic.
# Legitimate | It appears to be a job posting from a perl.org address.
# Legitimate | The email appears to be from a known sender with a technical subject.
# Phishing | The sender's email is not a trusted source and has a suspicious subject.
# Phishing | The sender's email address is suspicious and the subject line contains spam-like wording.
# Legitimate | It is from a known sender with an academic topic.
# Phishing | The subject line is suspicious and the sender's domain is not trustworthy.
# Legitimate | It appears to be a job posting from a perl.org email, which is likely legitimate.
# Legitimate | The sender's email address looks unusual but not explicitly malicious. Subject is normal.
# Phishing | The sender's email address looks suspicious.
# Phishing | The sender's email address seems unrelated to the subject, which promises happiness.
# Phishing | The sender's address looks suspicious.
# Phishing | The sender's email address looks suspicious.
# Phishing | The sender's email is suspicious and the subject contains spam-like content.
# Phishing | The sender's email address is unusual, and the subject line is suspicious.
# Legitimate | Email comes from a seemingly personal but valid email address, contains a subject related to a technical discussion, and has a normal date format.
# Phishing | The sender's email address looks suspicious and the subject is generic.
# ✅ Few-shot processed and saved → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/output_daata/fewshot/header_sample_75_without_label_fewshot_predicted.xlsx
# Phishing | Contains sexually suggestive language and a suspicious link.
# Phishing | Contains sexually suggestive content and a suspicious link.
# Legitimate | CNN Daily Top 10 news summary with links to CNN website.
# Legitimate | Technical discussion about email filtering and domain names.
# Phishing | Suspicious link and generic greeting.
# Phishing | Contains gibberish text and unusual formatting, which is often used to bypass spam filters.
# Phishing | Contains grammar errors and advertises counterfeit goods.
# Legitimate | Email from CNN with news and video links.
# Legitimate | Automated message from a bug tracking system, likely legitimate.
# Legitimate | This is a CNN Daily Top 10 email with valid CNN URLs and unsubscribe links.
# Phishing | Promises too good to be true and contains suspicious links.
# Phishing | Contains a suspicious link and promotes software sales, which could be unauthorized.
# Legitimate | Newsletter format with links to CNN content and unsubscribe information.
# Legitimate | Email from CNN with links to news articles and videos.
# Phishing | Promises unrealistic results and contains a suspicious link.
# Legitimate | Standard business communication with contact details.
# Legitimate | CNN Daily Top 10 news email with valid CNN links and unsubscribe information.
# Legitimate | Daily news update from a reputable source with clear subscription management options.
# Legitimate | Technical discussion from a mailing list.
# Legitimate | Email chain from a mailing list discussing technical issues related to software.
# Legitimate | Informational newsletter with clear links and unsubscribe options.
# Legitimate | Automated bug report with technical details and system configuration information.
# Legitimate | Standard mailing list message with subscription and management information.
# Legitimate | Automated message from a software repository, containing code changes and mailing list information.
# Legitimate | Technical discussion about system administration.
# Phishing | Suspicious message with a link.
# Phishing | Contains sexually suggestive content and a suspicious link.
# Legitimate | Technical discussion about Linux security; no phishing indicators.
# Phishing | Sexual content and suspicious link.
# Phishing | Promises degrees without coursework and uses multiple exclamation points.
# Legitimate | Email from CNN with news headlines and links, including unsubscribe information.
# Phishing | Contains suspicious links and unrelated words, promoting medication, and unusual formatting.
# Phishing | Contains a suspicious link and promises unrealistic results.
# Legitimate | Technical discussion about Perl programming and regular expressions.
# Legitimate | Informational email from a bookstore.
# Legitimate | CNN daily news email with valid links and unsubscribe information.
# Phishing | Contains a suspicious link and promotes sexually explicit content.
# Phishing | Generic health claim with a suspicious "click here" link.
# Legitimate | Automated email notification from a bug tracking system.
# Phishing | Suspicious link and encouragement to "take action now."
# Legitimate | Advertisement for a product.
# Legitimate | Daily news update from a reputable source (CNN).
# Legitimate | The email consists of nonsensical phrases and words, lacking a coherent structure or any recognizable topic. It does not contain any typical indicators of phishing attempts, such as urgent calls to action, suspicious links, or requests for personal information. Therefore, it is likely a legitimate email, though its purpose is unclear.
# Legitimate | Technical discussion and request for help.
# Legitimate | Newsletter from a news source with unsubscribe option.
# Legitimate | Technical discussion about operating system security.
# Phishing | Contains sexually suggestive content and a suspicious link.
# Legitimate | Newsletter from a reputable news source with standard disclaimers and unsubscribe option.
# Legitimate | Email appears to be a legitimate news update from CNN.com with standard disclaimers and unsubscribe information.
# Legitimate | Daily news update from a reputable source (CNN).
# Legitimate | Informational email about a conference and competition, including contact details and links to more information.
# Legitimate | Technical discussion; normal communication.
# Legitimate | Standard email thread and conversation.
# Legitimate | Standard bug report notification from a known open-source project.
# Legitimate | Job posting with standard details and contact information.
# Legitimate | Job posting with standard application instructions and links to reputable sites.
# Legitimate | Informational newsletter with multiple links.
# Legitimate | Job posting with contact information and company details.
# Phishing | Suspicious subject, generic message, and a likely malicious link.
# Legitimate | Job posting with standard details and contact information.
# Legitimate | Technical question about spam filter behavior.
# Phishing | Contains promises of easy money and a suspicious website link.
# Phishing | Promises guaranteed results and promotes a health product.
# Legitimate | Technical question about statistical analysis in R.
# Legitimate | This appears to be an excerpt from a news report or official document.
# Legitimate | Job posting with standard details and contact information.
# Phishing | Contains language common in pharmaceutical spam.
# Legitimate | Daily news email from a reputable source with clear unsubscribe options.
# Phishing | Contains suspicious language related to online pharmacies and random unrelated words.
# Legitimate | Newsletter from a reputable news source with clear links for managing subscriptions.
# Legitimate | Daily news update from a reputable source with clear unsubscribe options.
# Phishing | Offers prescription drugs without a doctor's visit and uses a suspicious website.
# Phishing | Advertisement for replica products with a suspicious link.
# Legitimate | Technical discussion on Python development mailing list.
# Phishing | Contains a suspicious link and promotional content.
# ✅ Few-shot processed and saved → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/output_daata/fewshot/body_sample_75_without_label_fewshot_predicted.xlsx
# Phishing | Suspicious sender, vague subject, and a link to an unknown website.
# Phishing | Suspicious sender, subject, and unsolicited link.
# Phishing | Sender address is suspicious, contains many links, and the email format is unusual for legitimate CNN emails.
# Legitimate | Technical discussion on email filtering, references to reputable sources (wikipedia.org, apache.org).
# Phishing | Suspicious sender, generic subject, and a link to a suspicious URL.
# Phishing | Suspicious sender, nonsensical body content.
# Phishing | Suspicious sender, unsolicited offer, and promotion of counterfeit goods.
# Legitimate | Email from CNN.com, contains news articles and links to CNN website, includes privacy guidelines and unsubscribe information.
# Legitimate | Automated email from a bug tracking system, standard format.
# Legitimate | Email from CNN with links to news articles and videos. Unsubscribe link is present.
# Phishing | Unsolicited offer, generic sender, and promises that seem too good to be true.
# Phishing | Unsolicited email with a suspicious link and generic subject.
# Legitimate | Email appears to be a legitimate news update from CNN, with unsubscribe links and standard disclaimers.
# Legitimate | CNN Daily Top 10 email with unsubscribe links.
# Phishing | Suspicious sender, contains links to unknown websites and promises unrealistic outcomes.
# Legitimate | Professional communication, clear context, and standard business email format.
# Legitimate | Email from CNN with links to news articles, includes unsubscribe information.
# Legitimate | Email from CNN with links to news articles.
# Legitimate | Technical discussion on an open-source project.
# Legitimate | Technical discussion on a mailing list, no suspicious elements.
# Legitimate | Email from a known scientific organization with clear content and unsubscribe options.
# Legitimate | This is an automated bug report from a perl.org address, likely not a phishing attempt.
# Legitimate | Mailing list digest from a university domain.
# Legitimate | Automated email from a known source code repository (sourceforge.net) related to code changes.
# Legitimate | Technical discussion, standard email format, no suspicious content.
# Phishing | Suspicious subject, unsolicited content, and a shortened link.
# Phishing | Suspicious content and a likely malicious link.
# Legitimate | Standard email thread, technical discussion, no suspicious elements.
# Phishing | Suspicious sender, generic subject, and a link to an unrelated website.
# Phishing | Suspicious sender, generic subject, and unrealistic claims about degrees.
# Legitimate | Email appears to be a legitimate news subscription from CNN, containing top stories and videos with direct CNN links.
# Phishing | Suspicious sender, generic subject, and pharmaceutical spam links.
# Phishing | Suspicious subject, unsolicited email, and suspicious link.
# Legitimate | Technical discussion, no suspicious elements.
# Legitimate | Request for information from a known bookseller email, no suspicious links.
# Phishing | Sender's address looks suspicious, contains many links.
# Phishing | Suspicious subject and URL.
# Phishing |Unsolicited email with a deceptive subject line and suspicious link.
# Legitimate | Automated email from a known open-source project issue tracker.
# Phishing | Suspicious subject, generic language, and unknown link.
# Phishing | Generic email, unsolicited offer, and suspicious sender domain.
# Legitimate | Email appears to be a legitimate CNN daily news update with valid links and unsubscribe information.
# Phishing | Gibberish content, unusual sender address, and nonsensical subject.
# Legitimate | Technical discussion, mailing list context, no suspicious links.
# Legitimate | From a known news source with clear unsubscribe information.
# Legitimate | This appears to be a discussion on an open-source mailing list, with no obvious phishing attempts.
# Phishing | Spam content related to erectile dysfunction with a suspicious link.
# Legitimate | Newsletter from a known news source with clear unsubscribe options.
# Legitimate | Email provides links to CNN and options to unsubscribe.
# Legitimate | Email from CNN with links to top news stories.
# Legitimate | Academic email with contact information and conference details.
# Legitimate | Technical discussion on a mailing list, no suspicious content.
# Legitimate | Plain text email, part of an existing conversation, no suspicious elements.
# Legitimate | Automated email from a bug tracking system, standard format, no suspicious elements.
# Legitimate | Job posting from a perl.org address, contains job details and unsubscribe information.
# Legitimate | Job posting from a perl.org mailing list, contains standard job details and links.
# Legitimate | Informational newsletter from a known organization with multiple links to their website.
# Legitimate | Job advertisement from a perl.org email, contains standard job posting information.
# Phishing | Suspicious sender, generic subject, and a link to a potentially malicious site.
# Legitimate | Job advertisement from a perl.org email address with standard job posting format and links to company website and job posting site.
# Legitimate | Technical discussion, no urgent requests, appears to be from a mailing list.
# Phishing | Suspicious sender, generic subject, and promises of easy money with a suspicious link.
# Phishing | Unsolicited offer, suspicious sender domain, and guarantee of results.
# Legitimate | Academic inquiry, standard email format, no suspicious elements.
# Phishing | Suspicious sender, irrelevant subject line, and suspicious link.
# Legitimate | Job posting from a perl.org address, clear job details, standard unsubscribe information.
# Phishing | Generic subject, unusual sender, and suspicious link.
# Legitimate | Email from CNN with clear links and unsubscribe options.
# Phishing | Generic greeting, suspicious claims, and unusual language patterns.
# Phishing | Generic content, unusual sender domain, and multiple links.
# Legitimate | Email appears to be a legitimate news update from CNN, with links to CNN.com and options to manage settings or unsubscribe.
# Phishing | Suspicious sender, prescription drug offers, and unusual URL.
# Phishing | Suspicious sender, unsolicited offer, and link to an unknown website.
# Legitimate | Technical discussion, no urgent requests or suspicious links, from a mailing list.
# Phishing | Suspicious sender, vague subject, and unsolicited link.
# ✅ Few-shot processed and saved → /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/output_daata/fewshot/header_body_sample_75_without_label_fewshot_predicted.xlsx

# %%
process_chain_of_thought("header_sample_75_without_label.csv", "header")
process_chain_of_thought("body_sample_75_without_label.csv", "body")
process_chain_of_thought("header_body_sample_75_without_label.csv", "combined")
# Out:
# Phishing | Reason: Unusual sender domain and generic subject line.
# Phishing | Reason: Subject line and sender address are suspicious.
# Phishing | Reason: Unusual sender domain for CNN content.
# Legitimate | Reason: Email appears to be a legitimate notification related to a software repository commit, based on the sender and subject.
# Phishing | Reason: Unsolicited email with a suspicious sender and subject.
# Phishing | Reason: Unsolicited email from an unknown sender.
# Phishing | Reason: Unsolicited email about replica watches from an unusual sender.
# Phishing | Reason: Sender domain does not match CNN.com.
# Legitimate | Reason: Email originates from issues.apache.org and relates to a bug report.
# Phishing | Reason: Sender email address does not match the supposed sender (CNN).
# Phishing | Reason: Unsolicited debt consolidation offer from an unusual sender domain.
# Phishing | Reason: Unrelated sender domain and subject.
# Phishing | Reason: Sender email domain doesn't match CNN.com.
# Phishing | Reason: Sender domain mismatch with subject.
# Phishing | Reason: Unfamiliar domain and generic subject.
# Phishing | Reason: Sender address domain (sailing.ie) is inconsistent with the subject (IRC Certificate Application).
# Phishing | Reason: Sender domain mismatch with subject content.
# Phishing | Reason: Sender domain doesn't match subject (CNN) and the domain looks suspicious.
# Legitimate | Reason: Likely a legitimate email from a forum.
# Legitimate | Reason: Seems like a normal mailing list email.
# Legitimate | Reason: The sender domain aligns with the subject and appears to be an alert service.
# Legitimate | Reason: Appears to be an automated message from a perl bug tracker.
# Legitimate | Reason: Email appears to be an automated digest from a university mailing list.
# Legitimate | Reason: Sourceforge sender, python.org receiver, check-in subject.
# Legitimate | Reason: Email appears to be a legitimate response within an opensuse mailing list based on sender and receiver domains and subject matter.
# Phishing | Reason: Subject line is highly suspicious.
# Phishing | Reason: Unsolicited order confirmation from an unknown sender.
# Legitimate | Reason: Sender and receiver are email addresses, subject is related to receiver list.
# Phishing | Reason: Unsolicited email about herbal products from an unusual sender.
# Phishing | Reason: Suspicious sender and subject.
# Phishing | Reason: Sender domain does not match CNN.com.
# Phishing | Reason: Unsolicited email about a "Man's stuff store" from an unusual sender.
# Phishing | Reason: Generic subject and unusual sender domain.
# Legitimate | Reason: Seemingly normal email exchange about a technical topic.
# Legitimate | Reason: Normal sender, receiver, and subject for book-related communication.
# Phishing | Reason: Suspicious sender address and subject mismatch.
# Phishing | Reason: Subject is suspicious and likely spam.
# Phishing | Reason: Suspicious subject line and sender combination.
# Legitimate | Reason: Appears to be an automated email from a bug tracking system (Apache).
# Phishing | Reason: Subject line is suspicious.
# Phishing | Reason: Unsolicited email about quitting smoking from an unknown sender.
# Phishing | Reason: Suspicious sender domain does not match CNN.com.
# Phishing | Reason: Suspicious sender domain and random subject.
# Legitimate | Reason: Email appears to be a legitimate announcement to a mailing list.
# Legitimate | Reason: Sender appears legitimate, subject matches sender, receiver is likely a trap.
# Legitimate | Reason: Email appears to be a normal mailing list message.
# Phishing | Reason: Subject is related to erectile dysfunction, which is a common phishing topic.
# Legitimate | Reason: Appears to be a legitimate newsletter from NBC11.com.
# Phishing | Reason: Sender domain does not match the subject.
# Legitimate | Reason: Sender domain matches subject content.
# Legitimate | Reason: Academic email about a spam challenge.
# Legitimate | Reason: Email appears to be a legitimate discussion thread regarding an openSUSE issue.
# Legitimate | Reason: Email appears to be a legitimate discussion within the opensuse community based on sender/receiver and subject.
# Legitimate | Reason: Email from apache.org regarding a bug report.
# Legitimate | Reason: Email appears to be a legitimate job posting from a perl.org sender to a perl.org receiver.
# Legitimate | Reason: Email originates from perl.org, a legitimate Perl organization.
# Legitimate | Reason: Sender appears legitimate based on sender and subject.
# Legitimate | Reason: Sender is perl.org and subject is relevant.
# Phishing | Reason: Unsolicited email with a generic subject and suspicious sender domain.
# Legitimate | Reason: Email from perl.org about Perl jobs.
# Legitimate | Reason: Appears to be a legitimate email from a known domain to a mailing list.
# Phishing | Reason: Suspicious subject and sender email mismatch.
# Phishing | Reason: Unsolicited money back guarantee from an unknown sender.
# Legitimate | Reason: Email appears to be a legitimate question to a mailing list.
# Phishing | Reason: Unsolicited email with suggestive subject from unknown sender.
# Legitimate | Reason: Email originates from perl.org, a legitimate domain for Perl jobs.
# Legitimate | Reason: Sender domain kp.org seems legitimate; no immediate red flags in subject/recipient.
# Phishing | Reason: Suspicious sender domain "shag.dealerspace.com" for a CNN Daily Top 10 email.
# Phishing | Reason: Suspicious sender and vague subject.
# Phishing | Reason: Sender domain does not match CNN.com.
# Phishing | Reason: Sender's email address doesn't match the purported sender (CNN).
# Phishing | Reason: Unsolicited email promoting prescription-free apothecary from an unusual sender.
# Phishing | Reason: Unsolicited email advertising replica watches from a suspicious sender.
# Phishing | Reason: Gmail address sending to a Python mailing list with a subject referencing a past date.
# Phishing | Reason: Unrelated sender domain and recipient address raise suspicion.
# ✅ CoT analysis complete for 'header' emails. File saved at: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/output_daata/chainofthought/header_sample_75_without_label_cot_predicted.xlsx
# Phishing | Reason: Contains suspicious link and promises related to sexual performance.
# Phishing | Reason: Suspicious link and inappropriate content.
# Legitimate| Reason: The email appears to be a legitimate CNN daily news update.
# Legitimate
# Phishing | Reason: Suspicious URL with Livefilestore redirection and generic greeting.
# Phishing | Reason: Garbled text and nonsensical content indicate a phishing attempt.
# Phishing | Reason: Offering replica watches is suspicious.
# Legitimate | Reason: The email appears to be a legitimate CNN Daily Top 10 email from 2008, with valid CNN links and standard disclaimers.
# Legitimate | Reason: Standard bug update notification from Apache.
# Legitimate | Reason: Appears to be a legitimate CNN daily news email.
# Phishing | Reason: Promises of eliminating debt without affecting credit are highly suspicious and likely a scam.
# Phishing | Reason: Generic link and suspicious product offer.
# Legitimate | Reason: Email appears to be a legitimate CNN daily news update from 2008 with standard disclaimers and unsubscribe links.
# Legitimate
# Phishing | Reason: Promotes sexual enhancement products with unrealistic claims and uses a suspicious link.
# Legitimate
# Legitimate | Reason: The email appears to be a legitimate CNN daily top 10 email from 2008.
# Legitimate
# Legitimate
# Legitimate | Reason: Email appears to be a forwarded message from a mailing list.
# Legitimate | Reason: Email seems to be a legitimate science newsletter.
# ERROR:tornado.access:500 POST /v1beta/models/gemini-2.0-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 178433.48ms
# Legitimate | Reason: This looks like an automated email from a mailing list.
# Legitimate | Reason: This email appears to be an automated notification of a code change in a software project.
# Legitimate | Reason: Technical discussion about disk usage, no suspicious requests.
# Phishing | Reason: Suspicious link and subject line.
# Phishing | Reason: Suspicious link and sexually suggestive content.
# Legitimate | Reason: Email is part of a technical discussion about Linux security.
# Phishing | Reason: Suspicious topic and link.
# Phishing | Reason: Offers diplomas without coursework or exams.
# Legitimate | Reason: Email appears to be a legitimate CNN daily news update with valid links and unsubscribe options.
# Phishing | Reason: Nonsensical words at the end of the email.
# Phishing | Reason: Suspicious link and vague claims of improving intimate life.
# Legitimate
# Legitimate | Reason: Email appears to be a genuine request for information from a bookstore.
# Legitimate
# Phishing | Reason: Suspicious link and sexually suggestive content.
# Phishing | Reason: Generic greeting and vague claim with a suspicious link.
# Legitimate | Reason: Email originates from apache.org and relates to a bug report.
# Phishing | Reason: Suspicious link and generic, enticing language.
# Phishing | Reason: Generic, unsolicited product advertisement with potential health claims.
# Legitimate | Reason: Appears to be a legitimate CNN Daily Top 10 email.
# Phishing | Reason: Nonsensical content and unusual word choices suggest a phishing attempt.
# Legitimate
# Legitimate | Reason: Email from a news source with unsubscribe link.
# Legitimate | Reason: Email is a discussion on operating system security.
# Phishing | Reason: Suspicious link and sexually suggestive content.
# Legitimate | Reason: Newsletter from NBC11.com with news articles and advertisements.
# Legitimate
# Legitimate
# Legitimate | Reason: Informational email about a legitimate conference.
# Legitimate | Reason: Technical discussion about disk space usage.
# Legitimate | Reason: Email is part of a discussion thread and contains no suspicious requests.
# Legitimate | Reason: Bug report notification from Apache.
# Legitimate | Reason: The email appears to be a job posting from perl.org, which is a legitimate source. The URLs provided seem related to the job and the organization.
# Legitimate | Reason: Email advertises a job posting with links to relevant job sites.
# Legitimate | Reason: Informational newsletter with multiple links to a legitimate organization.
# Legitimate | Reason: Appears to be a job posting from a legitimate source (perl.org and epsilon.com).
# Phishing | Reason: Suspicious subject and link.
# Legitimate | Reason: Job posting from a perl.org mailing list, links to reputable sites like dbds.com and jobs.perl.org.
# Legitimate | Reason: The email discusses a technical issue with a spam filter and seeks help with configuration, which is not inherently suspicious.
# Phishing | Reason: Generic promises of winning money and a suspicious link.
# Phishing | Reason: Unsolicited email promoting a product with a "guaranteed result" claim.
# Legitimate | Reason: Appears to be a genuine query on a statistical analysis method.
# Phishing | Reason: Contains sexually suggestive content and a suspicious link.
# Legitimate | Reason: Appears to be a job posting from a legitimate source.
# Phishing | Reason: Vague language and suspicious "check out here" link for medication.
# Legitimate | Reason: Email appears to be a legitimate CNN daily top 10 email from 2008, with valid CNN URLs.
# Phishing | Reason: Vague claims, generic language, and unusual word list suggest spam/phishing.
# Legitimate
# Legitimate | Reason: Appears to be a legitimate CNN daily top 10 email.
# Phishing | Reason: Offers prescription drugs without a prescription, which is illegal and highly suspicious.
# Phishing | Reason: Suspicious URL and offers of replica goods.
# Legitimate | Reason: This appears to be a digest from the Python-Dev mailing list, containing summaries of discussions and announcements.
# Phishing | Reason: Suspicious link and vague medicinal claims.
# ✅ CoT analysis complete for 'body' emails. File saved at: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/output_daata/chainofthought/body_sample_75_without_label_cot_predicted.xlsx
# Phishing | Reason: Suspicious link and subject.
# Phishing | Reason: Subject and body are sexually suggestive and lead to a suspicious website.
# Legitimate | Reason:Appears to be a legitimate CNN daily top 10 email.
# Legitimate
# Phishing | Reason: The link in the email body leads to a suspicious URL with a combination of random characters and file extensions, which is a common tactic in phishing attacks. The sender's email address also seems suspicious.
# Phishing | Reason: Gibberish content and suspicious sender.
# Phishing | Reason: Subject and body content suggest potential scam related to replica watches.
# Legitimate | Reason: The email appears to be a legitimate daily news update from CNN, with valid links and unsubscribe information.
# Legitimate | Reason: Email from Apache issues tracker, likely a notification.
# Legitimate | Reason: The email appears to be a legitimate CNN daily top 10 email.
# Phishing | Reason: Unsolicited debt elimination offer with suspicious link.
# Phishing | Reason: Unsolicited link to a suspicious website offering software.
# Legitimate | Reason:The email appears to be a legitimate CNN Daily Top 10 email, with standard disclaimers, unsubscribe links, and CNN copyright information.
# Legitimate | Reason: The email appears to be a legitimate CNN Daily Top 10 email based on the sender, content, and links.
# Phishing | Reason: Email promotes herbal products with unrealistic claims, typical of spam/phishing.
# Legitimate
# Legitimate
# Legitimate
# Legitimate | Reason: This email appears to be a legitimate discussion thread from a mailing list.
# Legitimate | Reason: The email appears to be a forwarded discussion within a mailing list.
# Legitimate | Reason: The email appears to be a legitimate science news alert from AAAS.
# Legitimate | Reason: Appears to be an automated bug report from a perl system.
# Legitimate | Reason: Standard mailing list digest from Waikato University.
# Legitimate | Reason: Automated email from sourceforge about code changes.
# Legitimate | Reason: Email appears to be a technical discussion on a mailing list.
# Phishing | Reason: Subject and body contain explicit content and instructions to visit a site, which is highly suspicious.
# Phishing | Reason: Suspicious link and body content.
# Legitimate | Reason: Email is a discussion on Linux security, no phishing indicators.
# Phishing | Reason: Suspicious link and subject matter from an unusual sender.
# Phishing | Reason: Offers degrees without coursework, exams, or interviews.
# Legitimate | Reason: Appears to be a legitimate CNN daily news email.
# Phishing | Reason: Suspicious sender, generic subject, and pharmaceutical spam content.
# Phishing | Reason: Suspicious link and vague subject line.
# Legitimate | Reason: Technical discussion about Perl regex scoping.
# Legitimate | Reason: Appears to be a legitimate inquiry from a bookstore.
# Legitimate | Reason: Email appears to be a legitimate CNN daily news update.
# Phishing | Reason: Suspicious link and subject matter from an unknown sender.
# Phishing | Reason: Subject line and body content are suspicious and irrelevant to the recipient's email address.
# Legitimate | Reason: Email originates from apache.org, relates to a bug report, and contains standard issue tracker notifications.
# Phishing | Reason: Generic language, suspicious link and mismatched sender.
# Phishing | Reason: Unsolicited email advertising a product, from an unusual sender.
# Legitimate | Reason:Email appears to be a legitimate CNN daily news update.
# Phishing | Reason: The email has a nonsensical subject and body with random words, indicating a phishing attempt.
# Legitimate | Email discusses technical issues with a software package.
# Legitimate | Reason: Email from a news source with unsubscribe link.
# Legitimate | Reason: Email is part of a discussion thread on OpenSuse, discussing security aspects of different OS.
# Phishing | Reason: The email promotes a suspicious website related to erectile dysfunction with an unsolicited link.
# Legitimate | Reason: Newsletter from a known news source.
# Legitimate
# Legitimate | Reason: Appears to be a legitimate CNN Daily Top 10 email.
# Legitimate | Reason: Appears to be a legitimate announcement for a conference and spam challenge.
# Legitimate | Reason: Technical discussion on opensuse mailing list.
# Legitimate | Reason: Email is part of an opensuse mailing list discussion.
# Legitimate | Reason: Email originates from apache.org, relates to a bug report, and contains standard notifications.
# Legitimate | Reason: Appears to be a legitimate job posting from perl.org.
# Legitimate | Reason: The email is a job posting from perl.org, referencing BBC, and provides relevant links.
# Legitimate | Sender seems legitimate and the email content aligns with the subject.
# Legitimate | Reason: Appears to be a legitimate job posting from Perl Jobs.
# Phishing | Reason: Suspicious link and subject with celebrity name.
# Legitimate | Reason: Appears to be a job posting from a perl.org mailing list.
# Legitimate | Reason: Email is a query to a mailing list with a previous communication quoted.
# Phishing | Reason: Subject line and body content are typical of spam/phishing emails promoting online casinos.
# Phishing | Reason: Unsolicited email promoting a product with a guarantee from a suspicious sender.
# Legitimate | Reason: Technical question posted to a mailing list.
# Phishing | Reason: Suspicious subject, sender, and link.
# Legitimate | Reason: Email appears to be a job posting from perl.org, linking to their jobs board.
# Phishing | Reason: Generic subject, suspicious link, and sender mismatch.
# Legitimate | Reason: Email appears to be a legitimate CNN daily top 10 email.
# Phishing | Reason: Unsolicited email offering medications from an unknown sender is suspicious.
# Phishing | Reason: Sender domain is not associated with CNN.
# Legitimate | Reason:The email appears to be a legitimate daily top 10 from CNN.com.
# Phishing | Reason: Selling prescription drugs without prescription is illegal and suspicious.
# Phishing | Reason: Suspicious sender, subject, and link.
# Legitimate | Reason: Appears to be a legitimate summary email from the Python development mailing list.
# Phishing | Reason: Suspicious sender, vague subject, medicinal options link, and unrelated text snippets.
# ✅ CoT analysis complete for 'combined' emails. File saved at: /content/drive/MyDrive/002 SP 25 Project/04 Manikanth and Anjireddy/001 Submission/All APIs/gemini_llm/output_daata/chainofthought/header_body_sample_75_without_label_cot_predicted.xlsx

# %%
import pandas as pd

# Function to summarize predictions in any result file
def summarize_predictions(filepath, prompt_type, email_type):
    try:
        # Load the prediction result file
        df = pd.read_excel(filepath)

        # Clean + Normalize the predictions
        df["Prediction"] = df["Prediction"].str.strip().str.lower()

        # Count the number of phishing and legitimate predictions
        phishing_count = (df["Prediction"] == "phishing").sum()
        legit_count = (df["Prediction"] == "legitimate").sum()
        total = len(df)

        # Print a summary
        print(f"\n {prompt_type.upper()} |  {email_type.upper()}")
        print(f" Total Emails: {total}")
        print(f" Phishing: {phishing_count}")
        print(f" Legitimate: {legit_count}")
        print("-" * 40)

    except Exception as e:
        print(f"❌ Error processing {filepath}: {e}")

# %%
# 🔹 Base path
base_path = os.path.join(path,'001 Submission','All APIs',  'gemini_llm', 'output_daata')

# 🔹 File and config list (path, type)
files_info = [
    # Zero-shot
    (f"{base_path}/zeroshot/header_sample_75_without_label_predicted.xlsx", "zero-shot", "header"),
    (f"{base_path}/zeroshot/body_sample_75_without_label_predicted.xlsx", "zero-shot", "body"),
    (f"{base_path}/zeroshot/header_body_sample_75_without_label_predicted.xlsx", "zero-shot", "combined"),

    # Few-shot
    (f"{base_path}/fewshot/header_sample_75_without_label_fewshot_predicted.xlsx", "few-shot", "header"),
    (f"{base_path}/fewshot/body_sample_75_without_label_fewshot_predicted.xlsx", "few-shot", "body"),
    (f"{base_path}/fewshot/header_body_sample_75_without_label_fewshot_predicted.xlsx", "few-shot", "combined"),

    # Chain-of-Thought
    (f"{base_path}/chainofthought/header_sample_75_without_label_cot_predicted.xlsx", "chain-of-thought", "header"),
    (f"{base_path}/chainofthought/body_sample_75_without_label_cot_predicted.xlsx", "chain-of-thought", "body"),
    (f"{base_path}/chainofthought/header_body_sample_75_without_label_cot_predicted.xlsx", "chain-of-thought", "combined"),
]

# Run summaries
for file_path, prompt_type, email_type in files_info:
    summarize_predictions(file_path, prompt_type, email_type)
# Out:
#  ZERO-SHOT |  HEADER
#  Total Emails: 75
#  Phishing: 53
#  Legitimate: 22
# ----------------------------------------
#
#  ZERO-SHOT |  BODY
#  Total Emails: 75
#  Phishing: 28
#  Legitimate: 47
# ----------------------------------------
#
#  ZERO-SHOT |  COMBINED
#  Total Emails: 75
#  Phishing: 29
#  Legitimate: 46
# ----------------------------------------
#
#  FEW-SHOT |  HEADER
#  Total Emails: 75
#  Phishing: 40
#  Legitimate: 35
# ----------------------------------------
#
#  FEW-SHOT |  BODY
#  Total Emails: 75
#  Phishing: 26
#  Legitimate: 49
# ----------------------------------------
#
#  FEW-SHOT |  COMBINED
#  Total Emails: 75
#  Phishing: 32
#  Legitimate: 43
# ----------------------------------------
#
#  CHAIN-OF-THOUGHT |  HEADER
#  Total Emails: 75
#  Phishing: 44
#  Legitimate: 31
# ----------------------------------------
#
#  CHAIN-OF-THOUGHT |  BODY
#  Total Emails: 75
#  Phishing: 29
#  Legitimate: 45
# ----------------------------------------
#
#  CHAIN-OF-THOUGHT |  COMBINED
#  Total Emails: 75
#  Phishing: 30
#  Legitimate: 45
# ----------------------------------------
